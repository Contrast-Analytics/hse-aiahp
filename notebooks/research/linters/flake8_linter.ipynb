# %%
import pandas as pd
import subprocess
import tempfile
import os
import json
from pandarallel import pandarallel

pandarallel.initialize(progress_bar=True)

solutions_train = pd.read_excel("data/for_teams/train/solutions.xlsx")
solutions_test = pd.read_excel("data/for_teams/test/solutions.xlsx")
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
def run_flake8_on_string(code_string: str):
    try:
        # Create a temporary file to hold the input Python code
        with tempfile.NamedTemporaryFile(delete=False, suffix=".py") as temp_file:
            temp_file_path = temp_file.name
            temp_file.write(code_string.encode("utf-8"))

        # Run pyright on the temporary file
        result = subprocess.run(
            ["flake8", "--format=json", "--select=E999", temp_file_path],
            capture_output=True,
            text=True,
        )

    except FileNotFoundError:
        print("Pyright is not installed or not found in your PATH.")
    except Exception as e:
        print(f"An error occurred: {e}")
    finally:
        pass
        # Clean up: Delete the temporary file
        if os.path.exists(temp_file_path):
            os.remove(temp_file_path)
            print(f"Temporary file {temp_file_path} deleted.")

    return result.stdout

def get_flake8_errors(code_string: str):
    basedpyright_output = run_flake8_on_string(code_string)
    lines = code_string.split("\n")
    errors = next(iter(json.loads(basedpyright_output).items()))[1]
    count = len(errors)
    if count == 0:
        return {
            "message": None,
            "line_number": None,
            "line": None,
        }
    errors = errors[0]

    return {
        "message": errors["text"],
        "line_number": errors["line_number"],
        "line": errors["physical_line"],
    }

# %%
solutions_train[["message", "line_number", "line"]] = solutions_train["student_solution"].parallel_apply(
    lambda x: pd.Series(get_flake8_errors(x))
)

solutions_train.to_csv("train_solutions_with_flake8.csv")
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=44), Label(value='0 / 44'))), HBox…
# Temporary file /tmp/tmp6vpqbapi.py deleted.
# Temporary file /tmp/tmprmg5k1t3.py deleted.
# Temporary file /tmp/tmpte5jjhs9.py deleted.
# Temporary file /tmp/tmpcb1jj76i.py deleted.Temporary file /tmp/tmpvhz2ydx8.py deleted.
#
# Temporary file /tmp/tmp65pvdf96.py deleted.
# Temporary file /tmp/tmptuz1flmd.py deleted.Temporary file /tmp/tmpvcolfx2_.py deleted.
#
# Temporary file /tmp/tmpzx7qypsb.py deleted.
# Temporary file /tmp/tmp7sx9g7im.py deleted.
# Temporary file /tmp/tmpe3_c97v5.py deleted.
# Temporary file /tmp/tmp6f383zqd.py deleted.
# Temporary file /tmp/tmp7nib1cha.py deleted.
# Temporary file /tmp/tmpzmf1qdia.py deleted.
# Temporary file /tmp/tmpbny_zh7e.py deleted.
# Temporary file /tmp/tmpi247f8dp.py deleted.
# Temporary file /tmp/tmp7l9g83xh.py deleted.
# Temporary file /tmp/tmp_hxm2k86.py deleted.
# Temporary file /tmp/tmp3txiozl8.py deleted.
# Temporary file /tmp/tmpthz1gvpf.py deleted.
# Temporary file /tmp/tmphdomxpl5.py deleted.
# Temporary file /tmp/tmp5nw5v4i4.py deleted.
# Temporary file /tmp/tmp5hjua_qx.py deleted.
# Temporary file /tmp/tmpy2i4d4_s.py deleted.
# Temporary file /tmp/tmp775zotbl.py deleted.
# Temporary file /tmp/tmpaybfb5n8.py deleted.
# Temporary file /tmp/tmpghthlth8.py deleted.
# Temporary file /tmp/tmp_0yp3jpb.py deleted.
# Temporary file /tmp/tmp3b1ybqhs.py deleted.
# Temporary file /tmp/tmpb9tkgka_.py deleted.
# Temporary file /tmp/tmp2xu9y7a7.py deleted.
# Temporary file /tmp/tmplcxbef60.py deleted.
# Temporary file /tmp/tmpkg8qho4p.py deleted.
# Temporary file /tmp/tmpdqk35fil.py deleted.
# Temporary file /tmp/tmpwnbqnd1h.py deleted.
# Temporary file /tmp/tmp62rrqjm7.py deleted.
# Temporary file /tmp/tmpbcb04eux.py deleted.
# Temporary file /tmp/tmpjrn9iotw.py deleted.
# Temporary file /tmp/tmp7qtevzba.py deleted.
# Temporary file /tmp/tmpr10w9l6d.py deleted.
# Temporary file /tmp/tmpoaa70vf6.py deleted.
# Temporary file /tmp/tmpfx2vu5ic.py deleted.
# Temporary file /tmp/tmp_shjeqkv.py deleted.
# Temporary file /tmp/tmp7qkbq1if.py deleted.
# Temporary file /tmp/tmpmnloy562.py deleted.
# Temporary file /tmp/tmpdx9yy65j.py deleted.Temporary file /tmp/tmpnst3afy8.py deleted.
#
# Temporary file /tmp/tmpiwou0wpo.py deleted.
# Temporary file /tmp/tmp82_hnctj.py deleted.
# Temporary file /tmp/tmpodjtuvec.py deleted.
# Temporary file /tmp/tmpnd68r7jj.py deleted.Temporary file /tmp/tmp4j4l81v5.py deleted.
#
# Temporary file /tmp/tmpquoqhd0o.py deleted.
# Temporary file /tmp/tmpmkurf8l8.py deleted.
# Temporary file /tmp/tmp5yc0gou7.py deleted.
# Temporary file /tmp/tmpkjcdapqj.py deleted.
# Temporary file /tmp/tmp6cov2p4a.py deleted.
# Temporary file /tmp/tmpg1anvj9f.py deleted.
# Temporary file /tmp/tmpaylt2ymk.py deleted.
# Temporary file /tmp/tmpl3v5bnth.py deleted.
# Temporary file /tmp/tmp9tsgyfps.py deleted.
# Temporary file /tmp/tmpyasw9wei.py deleted.
# Temporary file /tmp/tmp0q060fgq.py deleted.
# Temporary file /tmp/tmpi49cioz2.py deleted.
# Temporary file /tmp/tmpxygom05v.py deleted.
# Temporary file /tmp/tmpwd8xk15a.py deleted.
# Temporary file /tmp/tmp0nyh6zgm.py deleted.
# Temporary file /tmp/tmp7vhv7al2.py deleted.
# Temporary file /tmp/tmplgaz2xwe.py deleted.
# Temporary file /tmp/tmpnin9ei1l.py deleted.
# Temporary file /tmp/tmp9200y13l.py deleted.Temporary file /tmp/tmptp3ef4wk.py deleted.
#
# Temporary file /tmp/tmp8sc6ux5o.py deleted.
# Temporary file /tmp/tmpxm46k5gu.py deleted.
# Temporary file /tmp/tmpcqh6eauo.py deleted.Temporary file /tmp/tmpwwdt83rc.py deleted.
#
# Temporary file /tmp/tmp1a489m4g.py deleted.Temporary file /tmp/tmp67rroc18.py deleted.
#
# Temporary file /tmp/tmpolaqgm12.py deleted.
# Temporary file /tmp/tmpqzr6ltn4.py deleted.
# Temporary file /tmp/tmpbs00r35u.py deleted.
# Temporary file /tmp/tmp8yvvxw3j.py deleted.
# Temporary file /tmp/tmp2xq43k73.py deleted.
# Temporary file /tmp/tmpn4p01yym.py deleted.Temporary file /tmp/tmp0ccs_kc0.py deleted.
#
# Temporary file /tmp/tmpe5sq8pxa.py deleted.
# Temporary file /tmp/tmp3f_6ztt8.py deleted.
# Temporary file /tmp/tmpme6svril.py deleted.
# Temporary file /tmp/tmphocezci7.py deleted.
# Temporary file /tmp/tmp3s1iqoon.py deleted.
# Temporary file /tmp/tmpqihvh35p.py deleted.
# Temporary file /tmp/tmpmz3h89z4.py deleted.
# Temporary file /tmp/tmph5h7hzkl.py deleted.
# Temporary file /tmp/tmp244xtqup.py deleted.
# Temporary file /tmp/tmp04ln63a1.py deleted.
# Temporary file /tmp/tmpubdxi640.py deleted.
# Temporary file /tmp/tmpa1gdc453.py deleted.
# Temporary file /tmp/tmpaa3l698a.py deleted.
# Temporary file /tmp/tmp0g6___k5.py deleted.
# Temporary file /tmp/tmpb8z9m9ll.py deleted.
# Temporary file /tmp/tmpvyvuuk77.py deleted.
# Temporary file /tmp/tmpr2t948tz.py deleted.
# Temporary file /tmp/tmps8fe2w2c.py deleted.
# Temporary file /tmp/tmpx5x_x5o5.py deleted.
# Temporary file /tmp/tmp9fv0d8ap.py deleted.
# Temporary file /tmp/tmpvo2ehg8w.py deleted.
# Temporary file /tmp/tmp8yuwv0of.py deleted.
# Temporary file /tmp/tmpz0cqhazu.py deleted.
# Temporary file /tmp/tmp98j11nff.py deleted.
# Temporary file /tmp/tmpitqs0of7.py deleted.
# Temporary file /tmp/tmpgfm5e8iz.py deleted.
# Temporary file /tmp/tmpjfgezuwd.py deleted.
# Temporary file /tmp/tmp5as1k5lb.py deleted.
# Temporary file /tmp/tmp5sjhyiaf.py deleted.
# Temporary file /tmp/tmppl08re4e.py deleted.
# Temporary file /tmp/tmpxquwg_zy.py deleted.
# Temporary file /tmp/tmp890p40ht.py deleted.
# Temporary file /tmp/tmpslyz7yao.py deleted.
# Temporary file /tmp/tmpaavwg42b.py deleted.
# Temporary file /tmp/tmpiw1rnkli.py deleted.
# Temporary file /tmp/tmpqpzdeog7.py deleted.
# Temporary file /tmp/tmpsvfneabk.py deleted.
# Temporary file /tmp/tmphepajf0z.py deleted.
# Temporary file /tmp/tmpo3rzcsol.py deleted.
# Temporary file /tmp/tmpvrc4z6e7.py deleted.
# Temporary file /tmp/tmp57erqnss.py deleted.
# Temporary file /tmp/tmpn9_95z2z.py deleted.
# Temporary file /tmp/tmpf9zji3sx.py deleted.
# Temporary file /tmp/tmp4g6g98jc.py deleted.
# Temporary file /tmp/tmpm5b6s1vb.py deleted.
# Temporary file /tmp/tmpskbu5zsr.py deleted.
# Temporary file /tmp/tmpgyyc_tvo.py deleted.
# Temporary file /tmp/tmpewbk2f1y.py deleted.
# Temporary file /tmp/tmpq4qbfeq0.py deleted.Temporary file /tmp/tmp2q3aali7.py deleted.
#
# Temporary file /tmp/tmpnhg7fltj.py deleted.Temporary file /tmp/tmpwrk57m0m.py deleted.
#
# Temporary file /tmp/tmpgbm_1ozj.py deleted.
# Temporary file /tmp/tmp4i7x91th.py deleted.
# Temporary file /tmp/tmpto7r944_.py deleted.
# Temporary file /tmp/tmp57546tdc.py deleted.
# Temporary file /tmp/tmpjpdj_ov9.py deleted.
# Temporary file /tmp/tmpeu7_s2os.py deleted.
# Temporary file /tmp/tmpnpak9yer.py deleted.
# Temporary file /tmp/tmpe82xutpb.py deleted.
# Temporary file /tmp/tmp59msosee.py deleted.
# Temporary file /tmp/tmpnfyrkuk5.py deleted.
# Temporary file /tmp/tmpk89rpr1k.py deleted.
# Temporary file /tmp/tmpt45sxvwp.py deleted.Temporary file /tmp/tmpmygxvmkx.py deleted.
#
# Temporary file /tmp/tmp4znh0q91.py deleted.
# Temporary file /tmp/tmp7essak04.py deleted.
# Temporary file /tmp/tmp16ha4nvf.py deleted.
# Temporary file /tmp/tmp5_xkq8xq.py deleted.
# Temporary file /tmp/tmphfdkght0.py deleted.
# Temporary file /tmp/tmpxv7madtv.py deleted.
# Temporary file /tmp/tmpbhlvzm3i.py deleted.
# Temporary file /tmp/tmp08cu93e0.py deleted.
# Temporary file /tmp/tmpos0s4ojk.py deleted.
# Temporary file /tmp/tmpabjbeo3a.py deleted.
# Temporary file /tmp/tmp90e7xj9c.py deleted.
# Temporary file /tmp/tmpc5vqs8mk.py deleted.
# Temporary file /tmp/tmpf87bibrg.py deleted.
# Temporary file /tmp/tmpragfeebj.py deleted.
# Temporary file /tmp/tmp3vam0xql.py deleted.
# Temporary file /tmp/tmpumx9qbca.py deleted.Temporary file /tmp/tmpfp4rop2f.py deleted.
#
# Temporary file /tmp/tmp7ugb5dqn.py deleted.
# Temporary file /tmp/tmp2vax9nl_.py deleted.
# Temporary file /tmp/tmpj7k65zoy.py deleted.
# Temporary file /tmp/tmpo6wyx8rf.py deleted.
# Temporary file /tmp/tmpp7rr54wf.py deleted.
# Temporary file /tmp/tmpry0w5jcv.py deleted.
# Temporary file /tmp/tmpl1utsa0h.py deleted.
# Temporary file /tmp/tmpkoj83a_p.py deleted.
# Temporary file /tmp/tmprj7b0r7z.py deleted.
# Temporary file /tmp/tmpnqvco7_w.py deleted.
# Temporary file /tmp/tmpkk04z5oq.py deleted.
# Temporary file /tmp/tmpud96zhmc.py deleted.
# Temporary file /tmp/tmpbtjq9ctd.py deleted.
# Temporary file /tmp/tmpauct8qbf.py deleted.
# Temporary file /tmp/tmpdroljet3.py deleted.
# Temporary file /tmp/tmpcwg8obqw.py deleted.
# Temporary file /tmp/tmpu_4zu8vs.py deleted.
# Temporary file /tmp/tmpss8v1auk.py deleted.
# Temporary file /tmp/tmpjui_dmh2.py deleted.
# Temporary file /tmp/tmp_ma67_01.py deleted.
# Temporary file /tmp/tmp5d6mnq7a.py deleted.
# Temporary file /tmp/tmp1t_bb59j.py deleted.
# Temporary file /tmp/tmphju8rm45.py deleted.
# Temporary file /tmp/tmpii6w98tt.py deleted.
# Temporary file /tmp/tmpnux6blmn.py deleted.
# Temporary file /tmp/tmp5llm3yvo.py deleted.
# Temporary file /tmp/tmp0n50qfvd.py deleted.
# Temporary file /tmp/tmpecyehlli.py deleted.
# Temporary file /tmp/tmp4la5h_48.py deleted.
# Temporary file /tmp/tmpxoum72nw.py deleted.
# Temporary file /tmp/tmp3wrjajwj.py deleted.
# Temporary file /tmp/tmp2v8k5khg.py deleted.
# Temporary file /tmp/tmp6uznee_t.py deleted.
# Temporary file /tmp/tmpqezy6lnd.py deleted.
# Temporary file /tmp/tmpbop29hdw.py deleted.
# Temporary file /tmp/tmp79vm0_g4.py deleted.
# Temporary file /tmp/tmpwc3cztdn.py deleted.Temporary file /tmp/tmpwlr7zl01.py deleted.
#
# Temporary file /tmp/tmp2lzd_dxt.py deleted.
# Temporary file /tmp/tmp1d9umz3_.py deleted.
# Temporary file /tmp/tmpapa9wru6.py deleted.
# Temporary file /tmp/tmp96nrnux8.py deleted.
# Temporary file /tmp/tmplctdhbi5.py deleted.
# Temporary file /tmp/tmpmij8yhna.py deleted.
# Temporary file /tmp/tmp_suo5gki.py deleted.
# Temporary file /tmp/tmpa8_bdf4s.py deleted.
# Temporary file /tmp/tmp9szieipu.py deleted.
# Temporary file /tmp/tmpvom8grxb.py deleted.
# Temporary file /tmp/tmp9rmebr6g.py deleted.
# Temporary file /tmp/tmp3drq_dm6.py deleted.
# Temporary file /tmp/tmpv8gr_6l_.py deleted.
# Temporary file /tmp/tmp_hu3hlb9.py deleted.
# Temporary file /tmp/tmpqdofj8kv.py deleted.
# Temporary file /tmp/tmple43mv5m.py deleted.
# Temporary file /tmp/tmph586vzzs.py deleted.
# Temporary file /tmp/tmplwb135wp.py deleted.
# Temporary file /tmp/tmpxmn6x184.py deleted.Temporary file /tmp/tmp2cbdwlpd.py deleted.
#
# Temporary file /tmp/tmpffgdy3x3.py deleted.
# Temporary file /tmp/tmpw9hvyu54.py deleted.
# Temporary file /tmp/tmpye19el5u.py deleted.
# Temporary file /tmp/tmp8em7dzvb.py deleted.
# Temporary file /tmp/tmpgvn0oqnu.py deleted.
# Temporary file /tmp/tmpa49c1_mc.py deleted.
# Temporary file /tmp/tmpjjwtwsdf.py deleted.
# Temporary file /tmp/tmpdtqfzemp.py deleted.
# Temporary file /tmp/tmp1r68yt90.py deleted.
# Temporary file /tmp/tmp4o7btmzu.py deleted.
# Temporary file /tmp/tmpre55omcn.py deleted.
# Temporary file /tmp/tmp_aajz4fx.py deleted.
# Temporary file /tmp/tmpcq303014.py deleted.
# Temporary file /tmp/tmpc0x6uj0m.py deleted.
# Temporary file /tmp/tmp3b7mi5lp.py deleted.
# Temporary file /tmp/tmpc9zryuie.py deleted.
# Temporary file /tmp/tmph8x75y5p.py deleted.
# Temporary file /tmp/tmp2__5kxsm.py deleted.
# Temporary file /tmp/tmpkmys6hwy.py deleted.
# Temporary file /tmp/tmpaqk2w89z.py deleted.
# Temporary file /tmp/tmp3w5fsro3.py deleted.
# Temporary file /tmp/tmpa3j9oqv_.py deleted.
# Temporary file /tmp/tmpi_ee9zp7.py deleted.
# Temporary file /tmp/tmp1aru_91s.py deleted.
# Temporary file /tmp/tmpybr5_d6j.py deleted.
# Temporary file /tmp/tmps4dgo78p.py deleted.
# Temporary file /tmp/tmpthlm4r_3.py deleted.
# Temporary file /tmp/tmpduy9hht0.py deleted.
# Temporary file /tmp/tmpxuwlycat.py deleted.
# Temporary file /tmp/tmpj9ewkn07.py deleted.
# Temporary file /tmp/tmpcf_tgu03.py deleted.
# Temporary file /tmp/tmpd2ss1614.py deleted.
# Temporary file /tmp/tmp593hez66.py deleted.
# Temporary file /tmp/tmp8dzyu_ka.py deleted.
# Temporary file /tmp/tmppd4xpc0_.py deleted.
# Temporary file /tmp/tmp1u26xauv.py deleted.
# Temporary file /tmp/tmp5vozbsm2.py deleted.
# Temporary file /tmp/tmpsaxvs3cu.py deleted.
# Temporary file /tmp/tmp7p1cxrg6.py deleted.
# Temporary file /tmp/tmpe93j39y2.py deleted.
# Temporary file /tmp/tmpc2fi6scv.py deleted.
# Temporary file /tmp/tmp5r7fh3al.py deleted.
# Temporary file /tmp/tmp1lwe30f_.py deleted.
# Temporary file /tmp/tmpyosi0doa.py deleted.
# Temporary file /tmp/tmp26px71zk.py deleted.
# Temporary file /tmp/tmpzj5im0ih.py deleted.
# Temporary file /tmp/tmpi5hmq_0s.py deleted.
# Temporary file /tmp/tmp6yzues_2.py deleted.
# Temporary file /tmp/tmp_c7p64gf.py deleted.
# Temporary file /tmp/tmpua7ss20z.py deleted.
# Temporary file /tmp/tmppy77jji_.py deleted.
# Temporary file /tmp/tmpwie_bd13.py deleted.
# Temporary file /tmp/tmp_vcur24r.py deleted.
# Temporary file /tmp/tmppdalh4up.py deleted.
# Temporary file /tmp/tmpzydp_390.py deleted.Temporary file /tmp/tmpvgh80cda.py deleted.
#
# Temporary file /tmp/tmp5evdscms.py deleted.
# Temporary file /tmp/tmplh7r344r.py deleted.
# Temporary file /tmp/tmps68afnlv.py deleted.
# Temporary file /tmp/tmpof7j4crm.py deleted.
# Temporary file /tmp/tmpjvu7ek1c.py deleted.
# Temporary file /tmp/tmp58y24q9i.py deleted.
# Temporary file /tmp/tmp8isqn_do.py deleted.
# Temporary file /tmp/tmptq74cv3j.py deleted.
# Temporary file /tmp/tmp94bt5p0x.py deleted.
# Temporary file /tmp/tmp0oo1b4cf.py deleted.
# Temporary file /tmp/tmput4wprmq.py deleted.
# Temporary file /tmp/tmp541p5zmy.py deleted.
# Temporary file /tmp/tmpd1bnuokx.py deleted.
# Temporary file /tmp/tmp28d2219z.py deleted.
# Temporary file /tmp/tmpk7_37f_c.py deleted.
# Temporary file /tmp/tmpuq6d7agf.py deleted.
# Temporary file /tmp/tmp2qkkdgqx.py deleted.
# Temporary file /tmp/tmp6t8p7nvb.py deleted.
# Temporary file /tmp/tmpwwgcyyn7.py deleted.Temporary file /tmp/tmpjrvsf1s5.py deleted.
#
# Temporary file /tmp/tmpriifyvdv.py deleted.
# Temporary file /tmp/tmpavhx5xy_.py deleted.
# Temporary file /tmp/tmp98ac6nez.py deleted.
# Temporary file /tmp/tmp_8wzoja6.py deleted.
# Temporary file /tmp/tmpsdtn1_q9.py deleted.
# Temporary file /tmp/tmpvwpdry1f.py deleted.
# Temporary file /tmp/tmp_n_vd94s.py deleted.Temporary file /tmp/tmpa4b5fwn3.py deleted.
#
# Temporary file /tmp/tmpxrngjodu.py deleted.
# Temporary file /tmp/tmph_om3zod.py deleted.
# Temporary file /tmp/tmpcg9ud3i9.py deleted.
# Temporary file /tmp/tmp2uv77_cz.py deleted.
# Temporary file /tmp/tmplvplgrug.py deleted.
# Temporary file /tmp/tmphnwh2ize.py deleted.
# Temporary file /tmp/tmp4bov4l6p.py deleted.
# Temporary file /tmp/tmpfacueptu.py deleted.
# Temporary file /tmp/tmp5uyffvtm.py deleted.Temporary file /tmp/tmp4tfkdo_d.py deleted.
#
# Temporary file /tmp/tmp3qeqmeaq.py deleted.
# Temporary file /tmp/tmpta8s7lez.py deleted.
# Temporary file /tmp/tmpgzl0xzeb.py deleted.
# Temporary file /tmp/tmpe_m268d3.py deleted.
# Temporary file /tmp/tmp2hgz97bq.py deleted.
# Temporary file /tmp/tmppiatr6z7.py deleted.
# Temporary file /tmp/tmpyxvng3mq.py deleted.
# Temporary file /tmp/tmpvigdeops.py deleted.
# Temporary file /tmp/tmpghdufeei.py deleted.
# Temporary file /tmp/tmpuaid64p9.py deleted.
# Temporary file /tmp/tmpraso140n.py deleted.
# Temporary file /tmp/tmptvseseg0.py deleted.
# Temporary file /tmp/tmp3xj_y4w7.py deleted.
# Temporary file /tmp/tmpwm0_u99x.py deleted.
# Temporary file /tmp/tmp5c6whwxq.py deleted.
# Temporary file /tmp/tmprk03a_5p.py deleted.
# Temporary file /tmp/tmpvqdbvtbz.py deleted.
# Temporary file /tmp/tmpoaj1dpr7.py deleted.
# Temporary file /tmp/tmpvpkxdmm5.py deleted.
# Temporary file /tmp/tmp62r_j59u.py deleted.
# Temporary file /tmp/tmpaert78no.py deleted.
# Temporary file /tmp/tmpufupkriz.py deleted.
# Temporary file /tmp/tmpa5p1_u1d.py deleted.
# Temporary file /tmp/tmp1ywi5g3y.py deleted.
# Temporary file /tmp/tmp7htfzbq8.py deleted.
# Temporary file /tmp/tmpbi52svlf.py deleted.
# Temporary file /tmp/tmp93v5x6aj.py deleted.
# Temporary file /tmp/tmph_zejjmb.py deleted.

# %%
solutions_test[["message", "line_number", "line"]] = solutions_test["student_solution"].parallel_apply(
    lambda x: pd.Series(get_flake8_errors(x))
)

solutions_test.to_csv("test_solutions_with_flake8.csv")
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=41), Label(value='0 / 41'))), HBox…
# Temporary file /tmp/tmpak0tfsdu.py deleted.Temporary file /tmp/tmp6va544lj.py deleted.
#
# Temporary file /tmp/tmpn33027gz.py deleted.
# Temporary file /tmp/tmp4qktaglz.py deleted.
# Temporary file /tmp/tmpkb31zs0b.py deleted.
# Temporary file /tmp/tmps9dj1la7.py deleted.
# Temporary file /tmp/tmpib9ha818.py deleted.
# Temporary file /tmp/tmpvyu9k9w_.py deleted.
# Temporary file /tmp/tmp69omzls_.py deleted.Temporary file /tmp/tmpsfj956w8.py deleted.Temporary file /tmp/tmpke_4lx96.py deleted.
#
#
# Temporary file /tmp/tmpd4id8g_p.py deleted.
# Temporary file /tmp/tmpzv238x59.py deleted.
# Temporary file /tmp/tmpkakfw0fh.py deleted.
# Temporary file /tmp/tmpwlndek2j.py deleted.
# Temporary file /tmp/tmp46f7ujv3.py deleted.
# Temporary file /tmp/tmpy0f5wvpb.py deleted.
# Temporary file /tmp/tmp6xgkk0db.py deleted.
# Temporary file /tmp/tmpjz9_0t53.py deleted.
# Temporary file /tmp/tmprfk8oa5l.py deleted.
# Temporary file /tmp/tmp4i708hv9.py deleted.
# Temporary file /tmp/tmpdglg2x37.py deleted.
# Temporary file /tmp/tmpezbp3ugz.py deleted.
# Temporary file /tmp/tmp5zqtmg3h.py deleted.
# Temporary file /tmp/tmpv7hgievv.py deleted.Temporary file /tmp/tmpcd4vlin6.py deleted.
#
# Temporary file /tmp/tmpvgchbfb5.py deleted.
# Temporary file /tmp/tmpc_zbkutn.py deleted.
# Temporary file /tmp/tmpru6_dcur.py deleted.
# Temporary file /tmp/tmp493gkubb.py deleted.
# Temporary file /tmp/tmpby765ili.py deleted.
# Temporary file /tmp/tmp3maypt29.py deleted.
# Temporary file /tmp/tmpu8grcjkl.py deleted.
# Temporary file /tmp/tmp1g3mi6yc.py deleted.
# Temporary file /tmp/tmpj62_ubtx.py deleted.
# Temporary file /tmp/tmpi58n0oq5.py deleted.
# Temporary file /tmp/tmpwqtcbp5u.py deleted.Temporary file /tmp/tmpur5wy2ee.py deleted.
#
# Temporary file /tmp/tmpzcteuihx.py deleted.
# Temporary file /tmp/tmp28icfk69.py deleted.
# Temporary file /tmp/tmpmo235zr8.py deleted.
# Temporary file /tmp/tmpellox0vt.py deleted.
# Temporary file /tmp/tmp0am5z8bk.py deleted.
# Temporary file /tmp/tmpl7g6ay8p.py deleted.
# Temporary file /tmp/tmpddi92dun.py deleted.
# Temporary file /tmp/tmpc_c7b8yz.py deleted.
# Temporary file /tmp/tmpaoztusic.py deleted.
# Temporary file /tmp/tmpc5xemoyl.py deleted.
# Temporary file /tmp/tmp187tjv3o.py deleted.
# Temporary file /tmp/tmpxn097cfr.py deleted.
# Temporary file /tmp/tmpi1790wpo.py deleted.
# Temporary file /tmp/tmp1vyp5dqw.py deleted.
# Temporary file /tmp/tmp8si9ry_j.py deleted.
# Temporary file /tmp/tmpv1y0635y.py deleted.
# Temporary file /tmp/tmpvi1z9593.py deleted.Temporary file /tmp/tmpqsxk2mnk.py deleted.
#
# Temporary file /tmp/tmp80x5mjdy.py deleted.
# Temporary file /tmp/tmprbj6e83w.py deleted.
# Temporary file /tmp/tmpx4pph8qf.py deleted.
# Temporary file /tmp/tmpd_kxpjxr.py deleted.
# Temporary file /tmp/tmp7q9n0rd2.py deleted.
# Temporary file /tmp/tmpz36xqqh3.py deleted.Temporary file /tmp/tmp4a_jyb9m.py deleted.
#
# Temporary file /tmp/tmpdmum9zok.py deleted.
# Temporary file /tmp/tmpyt7_9qe0.py deleted.
# Temporary file /tmp/tmppp_7vc_c.py deleted.
# Temporary file /tmp/tmplp0a36b7.py deleted.
# Temporary file /tmp/tmpi2zw9cym.py deleted.
# Temporary file /tmp/tmp5z5b0doi.py deleted.
# Temporary file /tmp/tmpy0by618y.py deleted.
# Temporary file /tmp/tmpa44qk7zo.py deleted.
# Temporary file /tmp/tmpl7pt91aw.py deleted.
# Temporary file /tmp/tmpztl5yjna.py deleted.
# Temporary file /tmp/tmplhqe7joo.py deleted.
# Temporary file /tmp/tmp6bp2ppk1.py deleted.
# Temporary file /tmp/tmpndp6z85j.py deleted.
# Temporary file /tmp/tmpwwfv2__2.py deleted.
# Temporary file /tmp/tmpctvqwlzm.py deleted.
# Temporary file /tmp/tmp7rwqu3xe.py deleted.
# Temporary file /tmp/tmpkk5av2jm.py deleted.
# Temporary file /tmp/tmpr5g3g9jc.py deleted.
# Temporary file /tmp/tmpwmbd_i_b.py deleted.
# Temporary file /tmp/tmptzf41lo4.py deleted.
# Temporary file /tmp/tmpo6aq6odi.py deleted.
# Temporary file /tmp/tmpawvnchab.py deleted.
# Temporary file /tmp/tmpbc7tqn0b.py deleted.
# Temporary file /tmp/tmpyxpfwqnb.py deleted.
# Temporary file /tmp/tmppkgkebzn.py deleted.
# Temporary file /tmp/tmpt6le77ym.py deleted.
# Temporary file /tmp/tmp3mfctfja.py deleted.
# Temporary file /tmp/tmpr34neit4.py deleted.
# Temporary file /tmp/tmpb0q_jw5i.py deleted.
# Temporary file /tmp/tmpuukox1pq.py deleted.Temporary file /tmp/tmp91e6dya1.py deleted.
#
# Temporary file /tmp/tmpmv03a9b3.py deleted.
# Temporary file /tmp/tmp3rq6164p.py deleted.
# Temporary file /tmp/tmphq0uq0ks.py deleted.
# Temporary file /tmp/tmphz0rb5qw.py deleted.
# Temporary file /tmp/tmp3jo14ddn.py deleted.
# Temporary file /tmp/tmpi_hfzcrl.py deleted.
# Temporary file /tmp/tmpx_yipaib.py deleted.
# Temporary file /tmp/tmprswpstq1.py deleted.
# Temporary file /tmp/tmps_vmblr4.py deleted.
# Temporary file /tmp/tmpfuytmy3o.py deleted.
# Temporary file /tmp/tmp2gce15vh.py deleted.
# Temporary file /tmp/tmp6bd72n8o.py deleted.
# Temporary file /tmp/tmpq1bmpe7g.py deleted.
# Temporary file /tmp/tmpj1imypyl.py deleted.
# Temporary file /tmp/tmp1jqdxex0.py deleted.
# Temporary file /tmp/tmpj7vjcthl.py deleted.
# Temporary file /tmp/tmputu2neki.py deleted.
# Temporary file /tmp/tmpwxflcu1a.py deleted.
# Temporary file /tmp/tmp7ghp1spx.py deleted.
# Temporary file /tmp/tmpk6ilx5sq.py deleted.
# Temporary file /tmp/tmpznh_1lqt.py deleted.
# Temporary file /tmp/tmp1x6csyjt.py deleted.
# Temporary file /tmp/tmpvn2va67v.py deleted.
# Temporary file /tmp/tmp5wp_fib_.py deleted.Temporary file /tmp/tmpn1l0_tcv.py deleted.
#
# Temporary file /tmp/tmpodwwjhhp.py deleted.
# Temporary file /tmp/tmpystvgjra.py deleted.
# Temporary file /tmp/tmpucf8z79j.py deleted.
# Temporary file /tmp/tmpvdo_wf6d.py deleted.
# Temporary file /tmp/tmpejuj5azc.py deleted.Temporary file /tmp/tmpnsoi57ly.py deleted.
#
# Temporary file /tmp/tmpmf68n_j5.py deleted.
# Temporary file /tmp/tmpi2sa13j_.py deleted.
# Temporary file /tmp/tmpby73h5jm.py deleted.
# Temporary file /tmp/tmph_0pwtb4.py deleted.
# Temporary file /tmp/tmpq3a2p_vj.py deleted.
# Temporary file /tmp/tmpsda0acef.py deleted.Temporary file /tmp/tmp73kdvolk.py deleted.
#
# Temporary file /tmp/tmpuq5xhfra.py deleted.
# Temporary file /tmp/tmp6olrrxd8.py deleted.
# Temporary file /tmp/tmpmzl57cij.py deleted.
# Temporary file /tmp/tmphbkp2dky.py deleted.
# Temporary file /tmp/tmpupjtvm2r.py deleted.
# Temporary file /tmp/tmpfnc75acs.py deleted.
# Temporary file /tmp/tmp7q9jz6th.py deleted.
# Temporary file /tmp/tmpw4iet_fl.py deleted.
# Temporary file /tmp/tmp28k29blg.py deleted.
# Temporary file /tmp/tmp6zfvcu32.py deleted.
# Temporary file /tmp/tmpdlljc4xt.py deleted.
# Temporary file /tmp/tmprs3kf8mn.py deleted.
# Temporary file /tmp/tmp3fb6jhco.py deleted.
# Temporary file /tmp/tmp351wtzju.py deleted.
# Temporary file /tmp/tmpxmeni3_d.py deleted.
# Temporary file /tmp/tmp7q004d9a.py deleted.
# Temporary file /tmp/tmp_vhxj4tq.py deleted.
# Temporary file /tmp/tmpox7rzowx.py deleted.
# Temporary file /tmp/tmpjrhix0er.py deleted.
# Temporary file /tmp/tmpap823zu4.py deleted.
# Temporary file /tmp/tmpk6b7zvlq.py deleted.
# Temporary file /tmp/tmpltdw2oa0.py deleted.
# Temporary file /tmp/tmpe3k2post.py deleted.
# Temporary file /tmp/tmpxwkgwvfc.py deleted.
# Temporary file /tmp/tmpt2d6qq8q.py deleted.
# Temporary file /tmp/tmp4e5nh2p4.py deleted.
# Temporary file /tmp/tmpz057zmeh.py deleted.
# Temporary file /tmp/tmp4xm74u0m.py deleted.
# Temporary file /tmp/tmpcenbm3o5.py deleted.
# Temporary file /tmp/tmp5yoox4fi.py deleted.
# Temporary file /tmp/tmpm5kk362_.py deleted.
# Temporary file /tmp/tmpadiv4poi.py deleted.
# Temporary file /tmp/tmp_zvo46vc.py deleted.
# Temporary file /tmp/tmp9ze6kxl7.py deleted.
# Temporary file /tmp/tmpza9w4j48.py deleted.
# Temporary file /tmp/tmp1euwq4ve.py deleted.
# Temporary file /tmp/tmpcyjadg1u.py deleted.
# Temporary file /tmp/tmpy4tw6tfl.py deleted.
# Temporary file /tmp/tmp631l679z.py deleted.
# Temporary file /tmp/tmp81osvglu.py deleted.
# Temporary file /tmp/tmp9bab2h24.py deleted.
# Temporary file /tmp/tmpq63nmx3k.py deleted.
# Temporary file /tmp/tmp64cvbkl5.py deleted.
# Temporary file /tmp/tmpi07b1wom.py deleted.
# Temporary file /tmp/tmp0owu6_vs.py deleted.
# Temporary file /tmp/tmpm_ep1d_m.py deleted.
# Temporary file /tmp/tmp117m3a57.py deleted.
# Temporary file /tmp/tmpvw0iajjn.py deleted.
# Temporary file /tmp/tmpazg6ixom.py deleted.
# Temporary file /tmp/tmpwq8zizj4.py deleted.
# Temporary file /tmp/tmp99zgw24r.py deleted.
# Temporary file /tmp/tmpo1ae558t.py deleted.
# Temporary file /tmp/tmp6oktrfmq.py deleted.
# Temporary file /tmp/tmp4v06xps_.py deleted.
# Temporary file /tmp/tmpvy40jmnh.py deleted.
# Temporary file /tmp/tmpxf9dhw44.py deleted.
# Temporary file /tmp/tmpbs906l3e.py deleted.Temporary file /tmp/tmpszq18zn5.py deleted.
# Temporary file /tmp/tmpe7d6rt12.py deleted.
#
# Temporary file /tmp/tmpaex41vua.py deleted.
# Temporary file /tmp/tmpmkh1g1aa.py deleted.
# Temporary file /tmp/tmpdwmbvci4.py deleted.
# Temporary file /tmp/tmp3pghbgie.py deleted.Temporary file /tmp/tmp0vh1d_k3.py deleted.
#
# Temporary file /tmp/tmpavs2dv1w.py deleted.
# Temporary file /tmp/tmpjffpzssj.py deleted.
# Temporary file /tmp/tmpsxfuckdc.py deleted.
# Temporary file /tmp/tmpcsk1rdp4.py deleted.
# Temporary file /tmp/tmpli6_h6ud.py deleted.
# Temporary file /tmp/tmp333h4mzy.py deleted.
# Temporary file /tmp/tmpq036iw6n.py deleted.Temporary file /tmp/tmp9zve6p7q.py deleted.
#
# Temporary file /tmp/tmppqgehqpu.py deleted.
# Temporary file /tmp/tmpakqe7wzl.py deleted.
# Temporary file /tmp/tmp1ovi4i25.py deleted.
# Temporary file /tmp/tmpa6pyyyfq.py deleted.
# Temporary file /tmp/tmpo14w4_jf.py deleted.
# Temporary file /tmp/tmpp26ut9j3.py deleted.
# Temporary file /tmp/tmp_2_0d_p6.py deleted.
# Temporary file /tmp/tmptmajzig8.py deleted.
# Temporary file /tmp/tmpcofbdl31.py deleted.
# Temporary file /tmp/tmp3t043toz.py deleted.
# Temporary file /tmp/tmpbztudyj4.py deleted.
# Temporary file /tmp/tmp5m3f7w27.py deleted.
# Temporary file /tmp/tmpltd_8y4k.py deleted.
# Temporary file /tmp/tmp1y570dc8.py deleted.
# Temporary file /tmp/tmpxd_syzqo.py deleted.
# Temporary file /tmp/tmp_kki9a1x.py deleted.
# Temporary file /tmp/tmp70c0vz88.py deleted.
# Temporary file /tmp/tmp3csereyr.py deleted.
# Temporary file /tmp/tmpl2uddd8t.py deleted.
# Temporary file /tmp/tmpzqpjwfm_.py deleted.
# Temporary file /tmp/tmpl3jz1a7r.py deleted.Temporary file /tmp/tmpy3ntnb_s.py deleted.
#
# Temporary file /tmp/tmpetvh6jnh.py deleted.
# Temporary file /tmp/tmpkadndh9q.py deleted.
# Temporary file /tmp/tmpud5c45er.py deleted.
# Temporary file /tmp/tmps1exs9tb.py deleted.
# Temporary file /tmp/tmp8z1k5m08.py deleted.
# Temporary file /tmp/tmpbu4xv44o.py deleted.
# Temporary file /tmp/tmpnd4_ony3.py deleted.
# Temporary file /tmp/tmpmovkg8wp.py deleted.
# Temporary file /tmp/tmpu3rj_zxm.py deleted.
# Temporary file /tmp/tmpg0mwbkow.py deleted.
# Temporary file /tmp/tmpo64l35hg.py deleted.
# Temporary file /tmp/tmpboasjkuf.py deleted.
# Temporary file /tmp/tmp2ovv1j2_.py deleted.
# Temporary file /tmp/tmpuircmgq0.py deleted.Temporary file /tmp/tmpv6fy_fsu.py deleted.
#
# Temporary file /tmp/tmp6jm9ilzo.py deleted.
# Temporary file /tmp/tmpmn53cmyu.py deleted.
# Temporary file /tmp/tmpblhyc954.py deleted.
# Temporary file /tmp/tmpctmb10me.py deleted.
# Temporary file /tmp/tmpc74irtki.py deleted.
# Temporary file /tmp/tmp69ty65ml.py deleted.
# Temporary file /tmp/tmpj4lwd6b9.py deleted.
# Temporary file /tmp/tmp0qkxq6vo.py deleted.
# Temporary file /tmp/tmpxwi9p7o0.py deleted.
# Temporary file /tmp/tmpjj5papf9.py deleted.
# Temporary file /tmp/tmpoi2mpf8o.py deleted.
# Temporary file /tmp/tmp3rj1nz57.py deleted.
# Temporary file /tmp/tmpzfmnesqq.py deleted.
# Temporary file /tmp/tmpwlx2tgxp.py deleted.
# Temporary file /tmp/tmpvs_0jdnn.py deleted.
# Temporary file /tmp/tmp3fgynw2x.py deleted.
# Temporary file /tmp/tmp04v4sgac.py deleted.
# Temporary file /tmp/tmp30gp3tmo.py deleted.
# Temporary file /tmp/tmpnmvanjqm.py deleted.
# Temporary file /tmp/tmpbtsr6670.py deleted.
# Temporary file /tmp/tmp1w_24dos.py deleted.
# Temporary file /tmp/tmpl68n1yvm.py deleted.
# Temporary file /tmp/tmp7d1rqs6i.py deleted.Temporary file /tmp/tmp07_g2xrg.py deleted.
#
# Temporary file /tmp/tmprk6dz7bk.py deleted.
# Temporary file /tmp/tmprrmxpu7f.py deleted.
# Temporary file /tmp/tmpfrusm7de.py deleted.
# Temporary file /tmp/tmpz1udfr8y.py deleted.
# Temporary file /tmp/tmpaxh2icrp.py deleted.
# Temporary file /tmp/tmp8emy2t05.py deleted.
# Temporary file /tmp/tmpckptg44q.py deleted.Temporary file /tmp/tmpbp1eoqyo.py deleted.
#
# Temporary file /tmp/tmp3ajf52ky.py deleted.
# Temporary file /tmp/tmpx1_pnn2k.py deleted.
# Temporary file /tmp/tmppa2o_ca0.py deleted.
# Temporary file /tmp/tmpsh4ln8ha.py deleted.
# Temporary file /tmp/tmpbo3e08vc.py deleted.
# Temporary file /tmp/tmpw_qd8ufj.py deleted.
# Temporary file /tmp/tmpgu28vs75.py deleted.
# Temporary file /tmp/tmpcgfs07eh.py deleted.
# Temporary file /tmp/tmpnjborpaz.py deleted.
# Temporary file /tmp/tmp_0ii97ny.py deleted.
# Temporary file /tmp/tmp1e5d1m6e.py deleted.
# Temporary file /tmp/tmpwot28atr.py deleted.
# Temporary file /tmp/tmp3oqz2w2y.py deleted.
# Temporary file /tmp/tmp9yx9viea.py deleted.
# Temporary file /tmp/tmpoh874hn8.py deleted.
# Temporary file /tmp/tmpx0vn4g3d.py deleted.
# Temporary file /tmp/tmp9iz2rgs8.py deleted.
# Temporary file /tmp/tmpxw64lkka.py deleted.
# Temporary file /tmp/tmpzum59yxt.py deleted.
# Temporary file /tmp/tmpnaf8a36a.py deleted.
# Temporary file /tmp/tmp09o4bzxm.py deleted.
# Temporary file /tmp/tmpfj4u2t3x.py deleted.
# Temporary file /tmp/tmpj0xud2wy.py deleted.
# Temporary file /tmp/tmp2nuy6bkn.py deleted.
# Temporary file /tmp/tmpx0832rm0.py deleted.
# Temporary file /tmp/tmpku2nfyz3.py deleted.Temporary file /tmp/tmpsi4pycwj.py deleted.
#
# Temporary file /tmp/tmpx89u260h.py deleted.
# Temporary file /tmp/tmp6c9ak_br.py deleted.
# Temporary file /tmp/tmp2pz15q1q.py deleted.
# Temporary file /tmp/tmpag4j2kue.py deleted.
# Temporary file /tmp/tmptyk5mwo2.py deleted.
# Temporary file /tmp/tmpvob6j7sq.py deleted.Temporary file /tmp/tmp3r6z7jyi.py deleted.
# Temporary file /tmp/tmpm366ru4q.py deleted.
#
# Temporary file /tmp/tmpu3m1r2s7.py deleted.
# Temporary file /tmp/tmpu7vvgrvp.py deleted.
# Temporary file /tmp/tmpantm2l5w.py deleted.
# Temporary file /tmp/tmpt0xob5pc.py deleted.
# Temporary file /tmp/tmp366rumks.py deleted.
# Temporary file /tmp/tmprj8_mpdt.py deleted.
# Temporary file /tmp/tmpjiolgto4.py deleted.
# Temporary file /tmp/tmpznli83uq.py deleted.
# Temporary file /tmp/tmpbvjay8v8.py deleted.
# Temporary file /tmp/tmp0xy5n9td.py deleted.
# Temporary file /tmp/tmpuxu801bc.py deleted.
# Temporary file /tmp/tmpiw5_3zw7.py deleted.
# Temporary file /tmp/tmpwtdww0jh.py deleted.
# Temporary file /tmp/tmpysibw2x_.py deleted.
# Temporary file /tmp/tmp0wef1n6n.py deleted.
# Temporary file /tmp/tmphzz7rmnr.py deleted.
# Temporary file /tmp/tmpkvb7q9vv.py deleted.
