# %% [markdown]
# ### open deepcode response

# %%
# либы
# Основные библиотеки
import pandas as pd
import torch
from transformers import BertModel, BertTokenizer
from tqdm import tqdm  # Импорт tqdm для отображения прогресса
import numpy as np
import json
import os
import re
import io
import ast
import time
import tempfile
import subprocess
from collections import Counter
from multiprocessing import Process, Queue
from contextlib import redirect_stdout
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
import matplotlib.pyplot as plt
import requests


path_to_test_data = "../data/for_teams/test"

# %%
gigachat_response = pd.read_csv('../data/deepseek/submit_deepseek.csv')

# %%
df_solutions_test = pd.read_excel(f'{path_to_test_data}/solutions.xlsx')
df_tests_test = pd.read_excel(f'{path_to_test_data}/tests.xlsx')
df_tasks_test = pd.read_excel(f'{path_to_test_data}/tasks.xlsx')

# %%
if 'problem_message' not in df_solutions_test.columns:
    df_solutions_test['problem_message'] = ''
if 'line_with_code' not in df_solutions_test.columns:
    df_solutions_test['line_with_code'] = ''
if 'error_type' not in df_solutions_test.columns:
    df_solutions_test['error_type'] = ''

# %%
for index, row in df_solutions_test.iterrows():
    try:
        ast.parse(row['student_solution'])
    except SyntaxError as e:
        df_solutions_test.at[index, 'problem_message'] = str(e)
        df_solutions_test.at[index, 'error_type'] = type(e).__name__
        
        # Получаем строку кода, вызвавшую ошибку
        lines = row['student_solution'].split('\n')
        if e.lineno is not None and 1 <= e.lineno <= len(lines):
            df_solutions_test.at[index, 'line_with_code'] = lines[e.lineno - 1]
        else:
            df_solutions_test.at[index, 'line_with_code'] = ''

# %%
def prepare_data(df_solutions, df_tests, df_tasks):
    # 1 Проверяем, что код компилируется
    if "code_problem" not in df_solutions.columns:
        df_solutions["code_problem"] = False

    # Проходим по всему DataFrame и проверяем код в student_solution
    for index, row in df_solutions.iterrows():
        try:
            ast.parse(row["student_solution"])
        except SyntaxError as e:
            df_solutions.at[index, "code_problem"] = True

    # 2 Удаляем комментарии
    def remove_cyrillic_comments(text):
        # Регулярное выражение для поиска комментариев с кириллицей
        pattern = r"#[^#\n]*[\u0400-\u04FF]"
        # Замена найденных комментариев на пустую строку
        return re.sub(pattern, "", text)

    # Применение функции к столбцу student_solution
    df_solutions["student_solution"] = df_solutions["student_solution"].apply(remove_cyrillic_comments)

    # 3 Выполняем тесты
    def replace_input_with_values(code, input_values):
        # Разделяем код на строки
        code_lines = code.split('\n')

        # Если input_values — строка, разделяем её на отдельные значения
        if isinstance(input_values, str):
            input_values_list = input_values.split('\n')
        else:
            input_values_list = input_values

        input_value_index = 0
        inside_loop = False
        new_code_lines = []

        is_loop_input = False
        for line in code_lines:
            # Проверяем, начался ли цикл
            if re.search(r'\bwhile\b|\bfor\b', line):
                inside_loop = True

            # Если находим вызов input()
            if 'input()' in line and inside_loop:
                is_loop_input = True

            # Проверяем конец цикла
            if inside_loop and re.search(r'\bbreak\b|\bcontinue\b|\bpass\b|\breturn\b', line):
                inside_loop = False

        inside_loop = False
        # if is_loop_input:
        #     new_code_lines.extend('')

        input_before_loop_cnt = 0
        for line in code_lines:
            # print(line, '|', inside_loop)
            # Проверяем, начался ли цикл
            if re.search(r'\bwhile\b|\bfor\b', line):
                inside_loop = True
                if is_loop_input:
                    new_code_lines.append(f'input_index = -1')
                    new_code_lines.append(f'input_values = {input_values_list[input_before_loop_cnt:]}')

            # Если находим вызов input()
            if 'input()' in line:
                if is_loop_input and inside_loop:
                    new_code_lines.append(f'    input_index += 1')
                    value = 'input_values[input_index]'
                    is_loop_input = False
                else:
                    if is_loop_input and not inside_loop:
                        input_before_loop_cnt += 1
                    if input_value_index < len(input_values_list):
                        value = f'"{input_values_list[input_value_index]}"'
                        input_value_index += 1
                    else:
                        value = '""'  # Если не хватает входных данных

                # Заменяем input() на текущее значение
                line = re.sub(r'input\s*\(\s*\)', f'{value}', line, count=1)

            new_code_lines.append(line)

            # Проверяем конец цикла
            if inside_loop and re.search(r'\bbreak\b|\bcontinue\b|\bpass\b|\breturn\b', line):
                inside_loop = False

        return '\n'.join(new_code_lines)

    def execute_code_with_timeout(code, input_values, timeout=0.5):
        def target(queue, code, input_values):
            # Заменяем вызовы input() на передачу данных напрямую
            code = replace_input_with_values(code, input_values)
            # Перенаправляем стандартный вывод в буфер
            buffer = io.StringIO()
            with redirect_stdout(buffer):
                try:
                    exec(code)
                except Exception as e:
                    queue.put(f"Error: {str(e)}")
                    return

            # Получаем результат вывода
            output = buffer.getvalue().strip()
            queue.put(output)

        q = Queue()
        p = Process(target=target, args=(q, code, input_values))
        p.start()
        p.join(timeout)

        if p.is_alive():
            p.terminate()
            p.join()
            return "Timeout"
        else:
            return q.get()

    def checkout_tests(solutions, tests):
        # Добавляем колонки error_open и error_closed со значением False по умолчанию        
        solutions['error_open_tests'] = False
        solutions['error_closed_tests'] = False
        solutions['test_info'] = [[] for _ in range(len(solutions))]  # Новая колонка для хранения информации о тестах

        # Проходим по каждой строке в solutions с использованием tqdm для отображения прогресса
        for index, row in tqdm(solutions.iterrows(), total=solutions.shape[0], desc="Processing solutions"):
            if not row['code_problem']:
                task_id = row['task_id']
                student_solution = row['student_solution']

                # Фильтруем tests по task_id
                relevant_tests = tests[tests['task_id'] == task_id]

                # Проходим по каждому тесту с использованием tqdm для отображения прогресса
                for test_index, test_row in relevant_tests.iterrows():

                    test_id = test_row['id']
                    test_input = test_row['input']
                    expected_output = test_row['output']
                    test_type = test_row['type']

                    try:
                        actual_output = execute_code_with_timeout(student_solution, test_input)
                        # print(actual_output)
                        # Сравниваем результат с ожидаемым выводом
                        if "Timeout" not in actual_output and "Error" not in actual_output:
                            if actual_output != expected_output:
                                if test_type == 'open':
                                    solutions.at[index, 'error_open_tests'] = True
                                elif test_type == 'closed':
                                    solutions.at[index, 'error_closed_tests'] = True

                                # Добавляем информацию о тесте в колонку test_info
                                test_info = [test_input, expected_output, actual_output]
                                solutions.at[index, 'test_info'].append(test_info)
                    except Exception as e:
                        pass

        return solutions

    for task_id in df_tasks['id']:
        df_solutions.loc[df_solutions['task_id'] == task_id, 'description'] = df_tasks.loc[df_tasks['id'] == task_id, 'description'].values[0]
        df_solutions.loc[df_solutions['task_id'] == task_id, 'author_solution'] = df_tasks.loc[df_tasks['id'] == task_id, 'author_solution'].values[0]
    df_solutions = checkout_tests(df_solutions, df_tests)
    return df_solutions

# %%
df_solutions_test = prepare_data(df_solutions_test, df_tests_test, df_tasks_test)
df_solutions_test.head(10)
# Out:
# Processing solutions: 100%|██████████| 325/325 [01:05<00:00,  5.00it/s]
#    id  task_id                                   student_solution  \
# 0   0        0  discount  = float(input())\nmoney = int(input(...
# 1   1        0  discount  = float(input())\nmoney = int(input(...
# 2   2        0  discount  = float(input())\nmoney = int(input(...
# 3   3        0  discount  = float(input())\nmoney = int(input(...
# 4   4        0  discount  = float(input())\nmoney = int(input(...
# 5   5        0  discount  = float(input())\nmoney = int(input(...
# 6   6        0  discount  = float(input())\nmoney = int(input(...
# 7   7        0  discount  = float(input())\nmoney = int(input(...
# 8   8        0  discount  = float(input())\nmoney = int(input(...
# 9   9        0  discount  = float(input())\nmoney = int(input(...
#
#       author_comment  author_comment_embedding  \
# 0  Ваше предсказание                       NaN
# 1  Ваше предсказание                       NaN
# 2  Ваше предсказание                       NaN
# 3  Ваше предсказание                       NaN
# 4  Ваше предсказание                       NaN
# 5  Ваше предсказание                       NaN
# 6  Ваше предсказание                       NaN
# 7  Ваше предсказание                       NaN
# 8  Ваше предсказание                       NaN
# 9  Ваше предсказание                       NaN
#
#                                      problem_message  \
# 0
# 1  unterminated string literal (detected at line ...
# 2  unterminated string literal (detected at line ...
# 3
# 4
# 5  unterminated string literal (detected at line ...
# 6
# 7              unexpected indent (<unknown>, line 6)
# 8           '(' was never closed (<unknown>, line 6)
# 9
#
#                                       line_with_code        error_type  \
# 0
# 1  print(f'Реализация проекта будет стоить {money...       SyntaxError
# 2  print(fРеализация проекта будет стоить {money}...       SyntaxError
# 3
# 4
# 5  print(f"Реализация проекта будет стоить {money...       SyntaxError
# 6
# 7      print(f'Реализация проекта будет стоить {m...  IndentationError
# 8  print(f'Реализация проекта будет стоить {money...       SyntaxError
# 9
#
#    code_problem                                        description  \
# 0         False  Реализуйте программу, которая напечатает стоим...
# 1          True  Реализуйте программу, которая напечатает стоим...
# 2          True  Реализуйте программу, которая напечатает стоим...
# 3         False  Реализуйте программу, которая напечатает стоим...
# 4         False  Реализуйте программу, которая напечатает стоим...
# 5          True  Реализуйте программу, которая напечатает стоим...
# 6         False  Реализуйте программу, которая напечатает стоим...
# 7          True  Реализуйте программу, которая напечатает стоим...
# 8          True  Реализуйте программу, которая напечатает стоим...
# 9         False  Реализуйте программу, которая напечатает стоим...
#
#                                      author_solution  error_open_tests  \
# 0  discount  = float(input())\nmoney = int(input(...             False
# 1  discount  = float(input())\nmoney = int(input(...             False
# 2  discount  = float(input())\nmoney = int(input(...             False
# 3  discount  = float(input())\nmoney = int(input(...             False
# 4  discount  = float(input())\nmoney = int(input(...             False
# 5  discount  = float(input())\nmoney = int(input(...             False
# 6  discount  = float(input())\nmoney = int(input(...             False
# 7  discount  = float(input())\nmoney = int(input(...             False
# 8  discount  = float(input())\nmoney = int(input(...             False
# 9  discount  = float(input())\nmoney = int(input(...             False
#
#    error_closed_tests test_info
# 0               False        []
# 1               False        []
# 2               False        []
# 3               False        []
# 4               False        []
# 5               False        []
# 6               False        []
# 7               False        []
# 8               False        []
# 9               False        []

# %%
def create_test_requests(df_solutions_test, df_gigachat):
    def remove_empty_lines(text):
        return "\n".join([line for line in text.splitlines() if line.strip()])

    def create_request(row, df_gigachat_row):
        # Удаляем пустые строки в описании задачи
        description = remove_empty_lines(row['description'])
        req = f"Есть задача, описанная так: ${description}$."

        # Удаляем пустые строки в решении студента
        student_solution = remove_empty_lines(row['student_solution'])
        if student_solution:
            req += f" У меня есть решение: ${student_solution}$."

        if row["code_problem"]:
            # Удаляем пустые строки в сообщении об ошибке
            problem_message = remove_empty_lines(row['problem_message'])
            if problem_message:
                req += f" В коде есть ошибка: ${problem_message}$."
        else:
            if row["test_info"]:
                req += " Оно не проходит тесты."
                if len(row["test_info"]) > 0:
                    test = row["test_info"][0]                
                    if test[0] and test[1] and test[2]:
                        req += f" При вводе {test[0]} ожидалось {test[1]}, но я получаю {test[2]}.\n"

        req += "Используй этот ответ для формирования ответа: " + df_gigachat_row

        return req.replace('\n', '')

    # Создаем список словарей в нужном формате
    dataset_for_GPT = []

    system_message = {
        "role": "system",
        "text": (
        "Вы — профессиональный программист и наставник, задача которого — помогать другим улучшать свой код."
        "Ваша задача — давать краткие советы по исправлению ошибок, максимум в 3 предложения, не давая готового решения."
        "Дайте краткую подсказку для исправления ошибки, объясняя её в контексте задания. Предоставляйте только рекомендации, фокусируясь на логике."
        "Используйте в речи такие фразы, как: Ваш код, выполняет условия, попробуйте изменить, условия задания, некорректно выполняет, скорректировать ошибку, забыли поставить, задания например, условие if."
        "А также: ваш код некорректно, выполняет условия задания, код некорректно выполняет, ошибку ваш код, изменить условие if. "
        "Общайтесь уважительно, на Вы."
        ),
    }

    # Создаем список для датафрейма
    df_list = []

    # Добавляем новую колонку 'requests' в df_solutions_test
    if 'system_message' not in df_solutions_test.columns:    
        df_solutions_test['system_message'] = None
    if 'request_text' not in df_solutions_test.columns:    
        df_solutions_test['request_text'] = None

    for index, row in df_solutions_test.iterrows():
        request_text = create_request(row, df_gigachat.iloc[index]['author_comment'])
        dataset_for_GPT.append(
            {"request": [system_message, {"role": "user", "text": request_text}], "response": row["author_comment"]}
        )

        # Добавляем данные в список для датафрейма
        df_list.append({"system_message": system_message["text"], "request_text": request_text})

        # Заполняем новую колонку 'requests'
        df_solutions_test.at[index, 'system_message'] = system_message["text"]
        df_solutions_test.at[index, 'request_text'] = request_text

    # Создаем датафрейм из списка
    df_system_request_test = pd.DataFrame(df_list)

    # Сохраняем датафрейм в CSV файл
    df_system_request_test.to_excel("system_request_pairs.xlsx")

    # Сохраняем список словарей в JSON файл
    with open("dataset_for_GPT_testGIGA.json", "w", encoding="utf-8") as f:
        for entry in dataset_for_GPT:
            json.dump(entry, f, ensure_ascii=False)
            f.write("\n")

    # Возвращаем обновленный датафрейм
    return df_solutions_test

# %%
df_solutions_test = create_test_requests(df_solutions_test, gigachat_response)
print(df_solutions_test.iloc[0]['request_text'])
# Out:
# Есть задача, описанная так: $Реализуйте программу, которая напечатает стоимость реализации проекта со скидкой: В переменную dicount считывается размер скидки на реализацию проекта (вещественное число). Этот код уже написан.В переменную money считывается стоимость реализации проекта в тысячах (целое число). Этот код уже написан.Программа должна вывести фразу вида 'Реализация проекта будет стоить <стоимость> тыс. руб. без скидки. Со скидой стоимость составит <стоимость с учетом скидки> тыс. руб.'. Важно! В коде обязательно нужно использовать f-строку!$. У меня есть решение: $discount  = float(input())money = int(input())print('Реализация проекта будет стоить {money} тыс. руб. без скидки. Со скидой стоимость составит {money- (money * discount)} тыс. руб.')$.Используй этот ответ для формирования ответа:  Вы некорректно выполняете условия задания, используя переменную `money` в двух местах в f-строке. Вместо этого нужно использовать переменную `discount` для вычисления стоимости с учетом скидки.

# %%
# Функция для подсчета символов в строке
def count_characters(text):
    return len(text)

# Функция для подсчета символов в списке строк
def count_characters_in_list(text_list):
    return sum(count_characters(text) for text in text_list)

# Открываем JSON файл и читаем его содержимое
with open('dataset_for_GPT_testGIGA.json', 'r', encoding='utf-8') as f:
    lines = f.readlines()

max_request_characters = 0
max_response_characters = 0
request_exceeds_3999_count = 0

# Проходим по каждой строке JSON файла
for line in lines:
    entry = json.loads(line)
    
    # Подсчитываем символы в request
    request_characters = count_characters_in_list([msg['text'] for msg in entry['request']])
    if request_characters > max_request_characters:
        max_request_characters = request_characters
    
    # Проверяем, превышает ли request 3999 символов
    if request_characters > 3999:
        request_exceeds_3999_count += 1
    
    # Подсчитываем символы в response
    response_characters = count_characters(entry['response'])
    if response_characters > max_response_characters:
        max_response_characters = response_characters

print(f"Максимальное количество символов в request: {max_request_characters}")
print(f"Максимальное количество символов в response: {max_response_characters}")
print(f"Количество раз, когда request превышает 3999 символов: {request_exceeds_3999_count}")
# Out:
# Максимальное количество символов в request: 3810
# Максимальное количество символов в response: 17
# Количество раз, когда request превышает 3999 символов: 0

# %%
df_solutions_test.head(10)
# Out:
#    id  task_id                                   student_solution  \
# 0   0        0  discount  = float(input())\nmoney = int(input(...
# 1   1        0  discount  = float(input())\nmoney = int(input(...
# 2   2        0  discount  = float(input())\nmoney = int(input(...
# 3   3        0  discount  = float(input())\nmoney = int(input(...
# 4   4        0  discount  = float(input())\nmoney = int(input(...
# 5   5        0  discount  = float(input())\nmoney = int(input(...
# 6   6        0  discount  = float(input())\nmoney = int(input(...
# 7   7        0  discount  = float(input())\nmoney = int(input(...
# 8   8        0  discount  = float(input())\nmoney = int(input(...
# 9   9        0  discount  = float(input())\nmoney = int(input(...
#
#       author_comment  author_comment_embedding  \
# 0  Ваше предсказание                       NaN
# 1  Ваше предсказание                       NaN
# 2  Ваше предсказание                       NaN
# 3  Ваше предсказание                       NaN
# 4  Ваше предсказание                       NaN
# 5  Ваше предсказание                       NaN
# 6  Ваше предсказание                       NaN
# 7  Ваше предсказание                       NaN
# 8  Ваше предсказание                       NaN
# 9  Ваше предсказание                       NaN
#
#                                      problem_message  \
# 0
# 1  unterminated string literal (detected at line ...
# 2  unterminated string literal (detected at line ...
# 3
# 4
# 5  unterminated string literal (detected at line ...
# 6
# 7              unexpected indent (<unknown>, line 6)
# 8           '(' was never closed (<unknown>, line 6)
# 9
#
#                                       line_with_code        error_type  \
# 0
# 1  print(f'Реализация проекта будет стоить {money...       SyntaxError
# 2  print(fРеализация проекта будет стоить {money}...       SyntaxError
# 3
# 4
# 5  print(f"Реализация проекта будет стоить {money...       SyntaxError
# 6
# 7      print(f'Реализация проекта будет стоить {m...  IndentationError
# 8  print(f'Реализация проекта будет стоить {money...       SyntaxError
# 9
#
#    code_problem                                        description  \
# 0         False  Реализуйте программу, которая напечатает стоим...
# 1          True  Реализуйте программу, которая напечатает стоим...
# 2          True  Реализуйте программу, которая напечатает стоим...
# 3         False  Реализуйте программу, которая напечатает стоим...
# 4         False  Реализуйте программу, которая напечатает стоим...
# 5          True  Реализуйте программу, которая напечатает стоим...
# 6         False  Реализуйте программу, которая напечатает стоим...
# 7          True  Реализуйте программу, которая напечатает стоим...
# 8          True  Реализуйте программу, которая напечатает стоим...
# 9         False  Реализуйте программу, которая напечатает стоим...
#
#                                      author_solution  error_open_tests  \
# 0  discount  = float(input())\nmoney = int(input(...             False
# 1  discount  = float(input())\nmoney = int(input(...             False
# 2  discount  = float(input())\nmoney = int(input(...             False
# 3  discount  = float(input())\nmoney = int(input(...             False
# 4  discount  = float(input())\nmoney = int(input(...             False
# 5  discount  = float(input())\nmoney = int(input(...             False
# 6  discount  = float(input())\nmoney = int(input(...             False
# 7  discount  = float(input())\nmoney = int(input(...             False
# 8  discount  = float(input())\nmoney = int(input(...             False
# 9  discount  = float(input())\nmoney = int(input(...             False
#
#    error_closed_tests test_info  \
# 0               False        []
# 1               False        []
# 2               False        []
# 3               False        []
# 4               False        []
# 5               False        []
# 6               False        []
# 7               False        []
# 8               False        []
# 9               False        []
#
#                                       system_message  \
# 0  Вы — профессиональный программист и наставник,...
# 1  Вы — профессиональный программист и наставник,...
# 2  Вы — профессиональный программист и наставник,...
# 3  Вы — профессиональный программист и наставник,...
# 4  Вы — профессиональный программист и наставник,...
# 5  Вы — профессиональный программист и наставник,...
# 6  Вы — профессиональный программист и наставник,...
# 7  Вы — профессиональный программист и наставник,...
# 8  Вы — профессиональный программист и наставник,...
# 9  Вы — профессиональный программист и наставник,...
#
#                                         request_text
# 0  Есть задача, описанная так: $Реализуйте програ...
# 1  Есть задача, описанная так: $Реализуйте програ...
# 2  Есть задача, описанная так: $Реализуйте програ...
# 3  Есть задача, описанная так: $Реализуйте програ...
# 4  Есть задача, описанная так: $Реализуйте програ...
# 5  Есть задача, описанная так: $Реализуйте програ...
# 6  Есть задача, описанная так: $Реализуйте програ...
# 7  Есть задача, описанная так: $Реализуйте програ...
# 8  Есть задача, описанная так: $Реализуйте програ...
# 9  Есть задача, описанная так: $Реализуйте програ...

# %%
# Загрузка моделей
print("Loading models...", end="")
model_name = "DeepPavlov/rubert-base-cased-sentence"
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)
print("OK")

# Функция для получения эмбединга предложения
def get_sentence_embedding(sentence: str) -> torch.Tensor:
    inputs = tokenizer(sentence, return_tensors="pt", truncation=True, padding=True, max_length=128)
    with torch.no_grad():
        outputs = model(**inputs)
        embedding = outputs.last_hidden_state[:, 0, :].squeeze()
    return embedding

# Функция для преобразования строки в эмбединг
def string2embedding(string: str) -> torch.Tensor:
    return torch.Tensor([float(i) for i in string.split()])

# Функция для преобразования эмбединга в строку
def embedding2string(embedding: torch.Tensor) -> str:
    return " ".join([str(i) for i in embedding.tolist()])

# Функция для вычисления косинусного расстояния между двумя векторами

def cosine_distance(a, b):
    # Проверка и преобразование строк в numpy.array
    if isinstance(a, str):
        a = np.array(a.split(), dtype=float)       
    if isinstance(b, str):
        b = np.array(b.split(), dtype=float)
    
    # Проверка, что a и b являются numpy.array
    if not isinstance(a, np.ndarray) or not isinstance(b, np.ndarray):
        raise ValueError("Аргументы должны быть numpy.array или строками, которые можно преобразовать в numpy.array")
    
    dot_product = np.dot(a, b)
    norm_a = np.linalg.norm(a)
    norm_b = np.linalg.norm(b)
    return 1 - (dot_product / (norm_a * norm_b))

# Функция для вычисления среднего косинусного расстояния
def mean_cosine_distance(embeddings):
    n = len(embeddings)
    distances = []
    
    for i in range(n):
        for j in range(i + 1, n):
            dist = cosine_distance(embeddings[i], embeddings[j])
            distances.append(dist)
    
    return np.mean(distances)
# Out:
# Loading models...
# /home/choosen-one/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# OK

# %%
if 'response' not in df_solutions_test.columns:
    df_solutions_test['response'] = None
if 'resp_lenght' not in df_solutions_test.columns:
    df_solutions_test['resp_lenght'] = None
if 'sentence_cnt' not in df_solutions_test.columns:
    df_solutions_test['sentence_cnt'] = None
if 'author_comment_embedding' not in df_solutions_test.columns:
    df_solutions_test['author_comment_embedding'] = False

# %%
def get_predictions():
    # URL для запроса к API Yandex Cloud
    url = "https://llm.api.cloud.yandex.net/foundationModels/v1/completion"

    # Заголовки запроса
    headers = {
        "Content-Type": "application/json",
        "Authorization": "Bearer t1.9euelZrOmJ7LmZmMi5zKisyRxo-Qje3rnpWanMqLjIybi4mSkZuYi5yaypfl8_clejZH-e9jaG8b_t3z92UoNEf572Nobxv-zef1656VmpOayMaMnoyZmZuNkZidi5We7_zF656VmpOayMaMnoyZmZuNkZidi5We.7uWyc8WanYxNfDiHGvcMmycAucTNdikMW5gdUMAIxMc9bJJl-Hh8wVfZLs5OH6ntg2xFE83Drqldy-2g2wFXAQ",
        "x-folder-id": "b1g9kv27t3avpjnp1gpf"
    }

    # Счетчик отправленных запросов
    request_count = 0

    # Счетчик реально отправленных запросов
    real_request_count = 0

    def send_request_and_save_response(row):
        nonlocal request_count, real_request_count

        # Проверка, есть ли уже данные в столбце 'response'
        if pd.isna(row['response']):
            # Извлечение данных из датафрейма
            system_message = row['system_message']
            request_text = row['request_text']

            # Формирование данных для запроса
            data = {
                "modelUri": "ds://bt1mk8ar7svnotmmhh78",
                "completionOptions": {
                    "stream": False,
                    "temperature": 0.1,
                    "maxTokens": "2000"
                },
                "messages": [
                    {
                        "role": "system",
                        "text": system_message
                    },
                    {
                        "role": "user",
                        "text": request_text
                    }
                ]
            }

            while True:
                try:
                    # Отправка POST-запроса
                    response = requests.post(url, headers=headers, data=json.dumps(data))
                    response.raise_for_status()  # Проверка на ошибки HTTP

                    # Увеличение счетчика отправленных запросов
                    request_count += 1

                    response_json = response.json()
                    if 'result' in response_json and 'alternatives' in response_json['result']:
                        message_text = response_json['result']['alternatives'][0]['message']['text']
                        real_request_count += 1
                    else:
                        message_text = response_json

                    # Сохранение ответа в столбец 'author_comment'
                    df_solutions_test.at[index, 'author_comment'] = message_text

                    # Вычисление эмбединга текста
                    text_embedding = embedding2string(get_sentence_embedding(message_text))
                    df_solutions_test.at[index, 'author_comment_embedding'] = text_embedding      

                    # Вычисление количества символов в тексте
                    resp_lenght = len(message_text)
                    df_solutions_test.at[index, 'resp_lenght'] = resp_lenght

                    # Вычисление количества предложений в тексте
                    sentence_cnt = len(message_text.split('.'))
                    df_solutions_test.at[index, 'sentence_cnt'] = sentence_cnt

                    # Возвращаем текст сообщения
                    return message_text
                except requests.exceptions.RequestException as e:
                    if response.status_code == 429:  # "Too Many Requests"
                        print(f"Получен ответ 'Too Many Requests'. Повторная попытка через 1 секунду...")
                        time.sleep(1)  # Пауза перед повторной попыткой
                    else:
                        print(f"Ошибка при отправке запроса: {e}")
                        return None
        else:
            # Если данные уже есть, возвращаем их
            return row['response']

    # Отправка запросов только для первых 3 строк, где нет данных в столбце 'response'
    for index, row in tqdm(df_solutions_test.iterrows(), total=df_solutions_test.shape[0], desc="Processing"):
        if real_request_count > 326 or request_count >= 325:
            break
        df_solutions_test.at[index, 'response'] = send_request_and_save_response(row)
        time.sleep(0.1)  # Таймаут между запросами

    # Вывод ответов в нужном формате
    for index, row in df_solutions_test.iterrows():
        if not pd.isna(row['response']):
            print(f'{row["response"]}')

    print(f"Количество реально отправленных запросов: {real_request_count}")

# %%
get_predictions()
df_solutions_test['response'].isna().sum()
# Out:
# Processing:  13%|█▎        | 43/325 [01:18<10:31,  2.24s/it]
# Получен ответ 'Too Many Requests'. Повторная попытка через 5 секунд...
# Processing:  14%|█▍        | 45/325 [01:23<10:53,  2.33s/it]
# Получен ответ 'Too Many Requests'. Повторная попытка через 5 секунд...
# Processing:  14%|█▍        | 46/325 [01:26<11:37,  2.50s/it]
# Получен ответ 'Too Many Requests'. Повторная попытка через 5 секунд...
# Processing:  22%|██▏       | 72/325 [02:25<07:32,  1.79s/it]
# Получен ответ 'Too Many Requests'. Повторная попытка через 5 секунд...
# Processing:  24%|██▎       | 77/325 [02:38<08:54,  2.16s/it]
# Получен ответ 'Too Many Requests'. Повторная попытка через 5 секунд...
# Processing:  25%|██▍       | 80/325 [02:46<09:33,  2.34s/it]
# Получен ответ 'Too Many Requests'. Повторная попытка через 5 секунд...
# Processing:  28%|██▊       | 92/325 [03:12<08:07,  2.09s/it]
# Получен ответ 'Too Many Requests'. Повторная попытка через 5 секунд...
# Processing:  42%|████▏     | 136/325 [05:00<06:44,  2.14s/it]
# Получен ответ 'Too Many Requests'. Повторная попытка через 5 секунд...
# Processing:  54%|█████▎    | 174/325 [06:31<04:53,  1.94s/it]
# Получен ответ 'Too Many Requests'. Повторная попытка через 5 секунд...
# Processing:  56%|█████▌    | 181/325 [06:53<05:19,  2.22s/it]
# Получен ответ 'Too Many Requests'. Повторная попытка через 5 секунд...
# Processing:  56%|█████▋    | 183/325 [06:58<05:28,  2.31s/it]
# Получен ответ 'Too Many Requests'. Повторная попытка через 5 секунд...
# Processing:  59%|█████▉    | 193/325 [07:18<04:13,  1.92s/it]
# Получен ответ 'Too Many Requests'. Повторная попытка через 5 секунд...
# Processing:  70%|██████▉   | 227/325 [08:37<03:20,  2.05s/it]
# Получен ответ 'Too Many Requests'. Повторная попытка через 5 секунд...
# Processing:  70%|███████   | 228/325 [08:40<03:48,  2.35s/it]
# Получен ответ 'Too Many Requests'. Повторная попытка через 5 секунд...
# Processing:  74%|███████▍  | 241/325 [09:09<02:57,  2.11s/it]
# Получен ответ 'Too Many Requests'. Повторная попытка через 5 секунд...
# Processing:  83%|████████▎ | 271/325 [10:15<01:50,  2.04s/it]
# Получен ответ 'Too Many Requests'. Повторная попытка через 5 секунд...
# Processing:  84%|████████▍ | 273/325 [10:21<02:07,  2.45s/it]
# Получен ответ 'Too Many Requests'. Повторная попытка через 5 секунд...
# Processing:  86%|████████▌ | 279/325 [10:34<01:32,  2.00s/it]
# Получен ответ 'Too Many Requests'. Повторная попытка через 5 секунд...
# Processing: 100%|██████████| 325/325 [12:23<00:00,  2.29s/it]
# Вы некорректно выполняете условия задания, используя переменную `money` в двух местах в f-строке. Вместо этого нужно использовать переменную `discount` для вычисления стоимости с учетом скидки.
# Вы забыли закрыть кавычки в f-строке.
#
# Попробуйте изменить:
#
# print(f'Реализация проекта будет стоить {money} тыс. руб. без скидки. Со скидкой стоимость составит {money- (money * discount)} тыс. руб.)$
#
# на:
#
# print(f'Реализация проекта будет стоить {money} тыс. руб. без скидки. Со скидкой стоимость составит {money- (money * discount)} тыс. руб.'$
# Вы забыли поставить закрывающую кавычку.
#
# Попробуйте изменить условие if, чтобы исправить ошибку.
# Вы забыли поставить пробел между переменной и оператором.
#
# Ваш код некорректно выполняет условия задания. Ошибка заключается в том, что скидка применяется не к стоимости реализации проекта в тысячах, а к значению скидки, что приводит к неправильному расчету стоимости с учетом скидки. Попробуйте изменить условие if, чтобы скидка применялась корректно к стоимости реализации проекта.
# Вы некорректно выполняет условия задания. Вы используете значение переменной `money` без скидки в выводе, что не соответствует условию задачи. Попробуйте изменить условия вывода, чтобы указать стоимость без скидки.
# Вы забыли поставить закрывающую кавычку.
#
# Попробуйте изменить условие задания, чтобы закрыть f-строку корректно.
# Ваш код некорректно выполняет условия задания.
# В условии if не используется переменная money.
# Попробуйте изменить условие if, чтобы использовать переменную money.
# Вы забыли поставить двоеточие после условия if.
#
# Попробуйте изменить условие if, чтобы исправить ошибку.
# Вы забыли поставить скобку после условия if.
# Ваш код некорректно выполняет условия задания.
# Попробуйте изменить условие if, чтобы исправить ошибку.
# Ваш код некорректно выполняет условия задания. Вместо использования переменной money в выводе, вы используете money в выражении для скидки.
#
# Попробуйте изменить условие if, чтобы использовать переменную money в выводе.
# Вы забыли закрыть скобку в f-строке.
#
# Попробуйте изменить код, добавив закрывающую скобку в конце f-строки.
# Вы забыли поставить скобку после условия if.
# Ваш код некорректно выполняет условия задания.
# Попробуйте исправить ошибку, добавив скобку после условия if.
# Вы забыли закрыть скобку в функции print().
#
# Попробуйте изменить код, добавив закрывающую скобку в функцию print().
# Ваш код некорректно выполняет условие задания. Например, условие if.
#
# Задание требует, чтобы цвета были отсортированы в алфавитном порядке. Ваш код не выполняет это условие.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код выполняет условия задания, но не учитывает сортировку цветов в алфавитном порядке.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания относительно сортировки цветов. Ваш код корректно находит пересечение множеств, но не гарантирует сортировку результата в алфавитном порядке. Попробуйте изменить условие if, чтобы включить сортировку результата.
# Ваш код некорректно выполняет условия задания. В условии указано, что цвета должны быть отсортированы в алфавитном порядке, а ваш код сортирует их в обратном порядке из-за аргумента reverse=False. Попробуйте изменить условие сортировки на reverse=True.
# Ваш код выполняет условия задания, но некорректно выполняет сортировку. Ваш код сортирует цвета в обратном алфавитном порядке из-за использования reverse=False в sorted(). Попробуйте изменить условие сортировки на reverse=True.
# Вы используете метод sorted() с аргументом reverse=False, что означает сортировку по возрастанию, но вам нужно сортировать по убыванию, чтобы цвета были в алфавитном порядке. Попробуйте изменить reverse=False на reverse=True.
# Ваш код некорректно выполняет условия задания.
# Ваш код исключает цвета, которые не являются любимыми, что нарушает условия задания. Попробуйте изменить условие if для включения только тех цветов, которые разрешены и любимые, но не использованные ранее.
# Ваш код некорректно выполняет условия задания. Он пытается выполнить побитовые операции с множествами, что приводит к ошибкам. Попробуйте изменить порядок операций или использовать правильные операции для множеств.
# Вы забыли поставить закрывающую скобку в функции print().
# Ваш код некорректно выполняет условия задания. Попробуйте изменить условие if, чтобы исправить ошибку.
# Ваш код некорректно выполняет условия задания. Например, он не учитывает цвета, которые дизайнер уже использовал в предыдущих проектах.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания.
#
# Ваш код не выполняет условия задания, потому что вы используете set() для всех списков. Это может привести к потере информации о количестве повторений цветов, если они есть. Попробуйте изменить условие if, чтобы использовать списки вместо множеств для сохранения количества повторений цветов.
# Ваш код некорректно выполняет условия задания. Оператор and в данном контексте не подходит для нахождения пересечения множеств, так как он возвращает первый ложный операнд, если такой есть, или последний операнд, если все операнды истинны. Попробуйте изменить условие if, чтобы использовать оператор пересечения & для множеств.
# Ваш код некорректно выполняет условия задания. Вы не учитываете, что цвета в каждом списке уникальны, и используете операцию сложения списков, что приведет к дублированию цветов. Попробуйте изменить условия задания, чтобы использовать операции над множествами для избежания дублирования.
# Ваш код некорректно выполняет условия задания, так как не учитывает структуру данных словаря studios. Вместо того, чтобы проверять наличие введенного помещения в списках помещений для каждой студии, вы обращаетесь к ключам и значениям словаря studios, что приводит к ошибкам. Попробуйте изменить условие if, чтобы правильно проверять наличие помещения в списках помещений для каждой студии.
# Ваш код выполняет условия задания некорректно. Ваш код добавляет названия поселков, где студии не занимались дизайном интерьера введенного помещения, но не учитывает, что в одном поселке могут быть помещения, которые студии не занимались. Попробуйте изменить условие if, чтобы учитывать, что в одном поселке может быть несколько помещений, и нужно проверять все помещения поселка.
# Ваш код некорректно выполняет условия задания. Ваш код добавляет в список residences все названия поселков, где нет упоминания о введенном помещении, что приводит к дублированию названий поселков.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код выполняет условия задания, но некорректно выполняет условия задания. Ваш код добавляет названия поселков, где студии не занимались дизайном интерьера введенного помещения, но не учитывает, что в одном поселке могут быть разные помещения. Попробуйте изменить условия задания, чтобы учесть возможность наличия нескольких помещений в одном поселке.
# Ваш код некорректно выполняет условие задания. Ваш код добавляет в список residences все поселки, где встречается указанное помещение, а не те, где не встречается.
#
# Попробуйте изменить условие if, чтобы исправить ошибку.
# Ваш код выполняет условия задания, но некорректно выполняет условия задания. Ваш код добавляет названия поселков в список residences только если помещение room не встречается в списке помещений для данного поселка. Однако, вы используете метод add, который не существует для списков. Нужно использовать метод append для добавления элементов в список.
# Ваш код некорректно выполняет условия задания. Вы добавляете в список residences названия поселков, где студии не занимались дизайном интерьера введенного помещения, но затем выводите множество (set) residences, что приводит к потере порядка и возможности дубликатов. Попробуйте изменить условие добавления в список, чтобы сохранить порядок и убрать дубликаты.
# Ваш код некорректно выполняет условия задания. Ваш код добавляет все названия поселков, где помещение не найдено, что приводит к дублированию названий. Попробуйте изменить условие добавления названий поселков, чтобы они были уникальными.
# Ваш код некорректно выполняет условия задания. Ваш код добавляет в список residences все названия поселков, где нет указанного помещения, что приводит к дублированию названий. Попробуйте изменить условие добавления в список residences на проверку наличия помещения в списке v.
# Ваш код некорректно выполняет условия задания. Ваш код добавляет в список residences все названия поселков, где нет указанного помещения, что приводит к дублированию названий. Попробуйте изменить условие добавления в список residences на проверку, что помещение не найдено в списке v для каждой студии.
# Ваш код выполняет условия задания некорректно. Ваш код добавляет в список residences названия поселков, где не было введеного помещения, но не учитывает, что в одном поселке может быть несколько студий. Попробуйте изменить условие if, чтобы учесть возможность нескольких студий в одном поселке.
# Ваш код некорректно выполняет условия задания. Вы добавляете название помещения (room) в список (residences) даже если оно присутствует в списке помещений для данного поселка. Это приводит к тому, что в список (residences) добавляются лишние элементы, и в результате вы получаете неверный список поселков, где не выполнялись работы по данному помещению.
#
# Попробуйте изменить условие if, чтобы исправить ошибку.
# Ваш код некорректно выполняет условия задания. Ваш код добавляет названия поселков в кортеж residences, который затем преобразуется в множество, что приводит к потере порядка и возможности дубликатов. Попробуйте изменить условие if, чтобы исправить ошибку.
# Ваш код некорректно выполняет условия задания. Он добавляет в список `residences` названия поселков, где не было введеного помещения, но затем сортирует и выводит все поселки, что не соответствует требованию найти только те поселки, где не было указанного помещения. Попробуйте изменить условие if, чтобы выполнить его корректно.
# Вы забыли поставить двоеточие после условия if.
# Ваш код некорректно выполняет условия задания. Он добавляет название поселка в residences только если помещение room не встречается в списке помещений v для данной студии. Это приводит к тому, что в residences попадают только те поселки, где не было данного помещения, а нужно наоборот — добавлять поселки, где было данное помещение.
# Попробуйте изменить условие на if room in v: и скорректировать логику добавления поселков в residences.
# Вы забыли поставить двоеточие в условии if.
#
# Условие должно выглядеть следующим образом:
#
# if room not in v:
# Ваш код некорректно выполняет условия задания. Ваш код добавляет названия поселков, где помещение есть, а не где его нет. Попробуйте изменить условие проверки на противоположное.
# Вы некорректно выполняет условия задания, используя переменные `money` и `duration` в строке вывода без указания их значений. Попробуйте изменить строку вывода, чтобы использовать переменные `money` и `duration`.
# Вы забыли поставить закрывающую фигурную скобку в конце ф-строки.
#
# Попробуйте изменить код, добавив закрывающую фигурную скобку.
# Вы забыли поставить закрывающую кавычку.
#
# Попробуйте изменить условие if, чтобы исправить синтаксическую ошибку.
# Ваш код некорректно выполняет условия задания.
# Вместо ввода пользователем значений для `duration` и `money`, в коде используются фиксированные значения 500 и 10 соответственно.
# Попробуйте изменить условие if, чтобы исправить ошибку.
# Вы забыли закрыть кавычки.
#
# Попробуйте изменить код, чтобы исправить ошибку.
# Вы некорректно выполняете условия задания, используя переменные money и duration в строке вывода.
#
# Вместо них нужно использовать переменные money и duration, которые уже были считаны ранее.
#
# Попробуйте изменить строку вывода следующим образом:
# print(f'Реализация проекта будет стоить {money} тыс. руб. Срок реализации проекта - {duration} недель.')
# Вы забыли преобразовать стоимость проекта в целое число.
#
# Ваш код некорректно выполняет условия задания.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Вы забыли поставить кавычки при использовании f-строки.
# Ваш код некорректно выполняет условия задания.
# Попробуйте скорректировать ошибку.
# Ваш код некорректно выполняет условия задания.
# Вывод должен быть в формате f-строки, где стоимость и срок реализации проекта меняются местами.
# Попробуйте изменить порядок аргументов в f-строке.
# Вы некорректно выполняет условия задания.
#
# Вместо "Print" нужно использовать "print".
# Вы забыли поставить двоеточие после условия if.
#
# Ваш код некорректно выполняет условия задания.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Ваш код проверяет, что цвет есть только в списке cite_project, но не учитывает возможность, что цвет может быть в обоих списках. Попробуйте изменить условие if, чтобы учесть возможность наличия цвета в обоих списках.
# Вы забыли поставить скобку после условия if.
#
# Ваш код некорректно выполняет условия задания. Вы пытаетесь проверить, что цвет есть в обоих списках, что противоречит условию задачи. Условие требует проверки, что цвет есть только в списке `cite_project` и отсутствует в `logo_project`. Попробуйте изменить условие проверки.
# Обратите внимание, что в условии if необходимо добавить условие, что цвет должен быть в списке cite_project.
# Ваш код проверяет, что цвет не встречается ни в одном из списков, что противоречит условию задания.
# Вы забыли поставить скобку в условии if.
#
# Ваш код некорректно выполняет условия задания, так как логика не соответствует заданию.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Вы забыли поставить скобку после условия if.
#
# Ваш код некорректно выполняет условия задания. Программа должна проверять, что цвет color есть только в списке cite_project, и если да, то печатать True. В остальных случаях программа печатает False.
#
# Ваш код проверяет, что цвет не в logo_project и есть в cite_project, что является противоположным условию. Попробуйте изменить условие if.
# Вы забыли поставить двоеточие после условия if.
# Ваш код некорректно выполняет условия задания. В условии указано, что нужно проверить, что цвет есть только в списке cite_project и не должен присутствовать в logo_project. Ваш код проверяет, что цвет не в logo_project и в cite_project, что является противоположным условию. Попробуйте изменить условие if.
# Ваш код проверяет наличие цвета в списке logo_project, что не соответствует условию задачи.
#
# Попробуйте изменить условия проверки, чтобы цвет проверялся только в списке cite_project.
# Вы забыли поставить двоеточие после условия if.
#
# Ваш код некорректно выполняет условия задания. Он будет истинно только если цвет отсутствует в logo_project и присутствует в cite_project, что противоречит условию задания. Попробуйте изменить условия проверки.
# Вы забыли поставить скобку после условия if.
#
# Ваш код некорректно выполняет условия задания, потому что не проверяет все условия.
#
# Попробуйте изменить условие if.
# Вы забыли поставить двоеточие после else.
#
# Ваш код некорректно выполняет условия задания. Условие требует проверки, что цвет есть только в списке cite_project и нет в logo_project. Ваш код проверяет, что цвет не в logo_project и есть в cite_project, что является обратной логикой. Попробуйте изменить условие if.
# Вы забыли поставить скобку после условия if.
#
# Ваш код некорректно выполняет условия задания. В данном случае, если цвет есть в списке `cite_project`, но отсутствует в `logo_project`, должно выводиться `True`.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код проверяет, что цвет не в logo_project, и выводит True, что не соответствует условию задания.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания.
# Ваш код разделяет упоминания, но не учитывает, что упоминания отделены от другого текста пробелом. Попробуйте изменить условие if, чтобы учитывать разделение упоминаний пробелами.
# Вы забыли поставить запятую после условия if.
#
# Ваш код некорректно выполняет условия задания.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания.
#
# Вместо @ должен быть пробел.
#
# Попробуйте изменить условие if.
# Ваш код некорректно выполняет условия задания. Упоминания не должны начинаться с '@'. Попробуйте изменить условие if.
# Ваш код некорректно выполняет условия задания. Например, условие if.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Вы забыли поставить знак == при проверке условия.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код добавляет упоминания в список `res` в порядке их обнаружения, что не всегда соответствует порядку в исходном тексте.
#
# Попробуйте изменить условие цикла for так, чтобы элементы списка `res` добавлялись в соответствии с порядком их появления в тексте.
# Ваш код некорректно выполняет условия задания. Условие задания требует вывода всех упоминаний через запятую с пробелом, но ваш код выводит все элементы из списка `res`, а не упоминания.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания.
#
# Ваш код проверяет, что все символы после первого "@" являются цифрами или буквами. Однако, если после "@" идут другие символы, а затем цифры или буквы, то код не будет работать корректно.
#
# Попробуйте изменить условие if, чтобы учесть это требование.
# Ваш код некорректно выполняет условия задания. Например, условие if.
#
# Ваш код не выполняет условия задания, потому что добавляет весь текст logo в список.
#
# Попробуйте изменить условие if, чтобы добавить в список не весь текст logo, а только упоминания.
# Ваш код некорректно выполняет условия задания. Например, условие if.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Например, условие if.
#
# Ваш код некорректно выполняет условия задания, потому что Вы используете метод isalnum() неправильно. Метод isalnum() проверяет, состоит ли строка только из буквенно-цифровых символов, включая символ @, что приводит к неправильной проверке. Вам нужно проверять только символы после @. Попробуйте изменить условие проверки символов после @.
# Ваш код некорректно выполняет условия задания. Логика проверки символов после '@' не учитывает, что упоминание может содержать только цифры или буквы, но не начинаться с них. Попробуйте изменить условие проверки символов после '@'.
# Ваш код некорректно выполняет условия задания. Программа должна выводить упоминания в том порядке, в котором они встречаются в тексте, а не сортировать их. Попробуйте изменить условие if.
# Ваш код некорректно выполняет условия задания.
#
# Вместо использования isnumeric() и isalpha() для проверки символов после @, попробуйте изменить условие if, чтобы использовать регулярное выражение, чтобы убедиться, что строка состоит только из букв и цифр.
# Ваш код некорректно выполняет условия задания. Вы вычитаете allowed_colors из пересечения used_colors и favorite_colors, что приведет к удалению всех разрешенных цветов из результата, а не наоборот. Попробуйте изменить порядок операций, чтобы сначала отфильтровать цвета, разрешенные для использования, а затем искать пересечения с любимыми цветами и уже использованными цветами.
# Ваш код некорректно выполняет условия задания. Выражение used_colors & favorite_colors - allowed_colors не дает правильный результат, так как операция вычитания множеств (-) не поддерживается для множеств в Python. Попробуйте изменить логику вычисления, чтобы получить правильный результат.
# Ваш код выполняет условия задания, но некорректно выполняет сортировку цветов. Ваш код выводит разность множеств, но не сортирует результат перед выводом. Попробуйте изменить условия задания, чтобы включить сортировку.
# Ваш код некорректно выполняет условия задания. Например, условие if.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Вы забыли поставить скобку после условия if.
# Ваш код некорректно выполняет условия задания, так как не выполняет сортировку по убыванию.
# Попробуйте изменить параметр reverse на True.
# Ваш код выполняет условия задания, но некорректно выполняет сортировку цветов. Ваш код сортирует цвета в обратном алфавитном порядке, так как использует reverse=False, что означает сортировку по возрастанию. Попробуйте изменить это на reverse=True для сортировки по убыванию.
# Ваш код некорректно выполняет условия задания. Он пытается отсортировать цвета в обратном алфавитном порядке, что не соответствует условию задачи.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Ошибка заключается в том, что он использует оператор and вместо & для пересечения множеств, что приводит к неправильному результату. Оператор and возвращает первый ложный операнд, если таковой имеется, что не соответствует логике пересечения множеств.
#
# Попробуйте изменить условие if, чтобы исправить ошибку.
# Ваш код некорректно выполняет условия задания. В условии указано, что цвета должны быть отсортированы в алфавитном порядке, а Ваш код использует reverse=False, что означает сортировку по возрастанию, а не по алфавиту. Попробуйте изменить условия сортировки.
# Ваш код некорректно выполняет условия задания. В вашем решении используется операция сложения множеств used_colors + favorite_colors, что приводит к дублированию элементов, которые присутствуют в обоих множествах. Попробуйте изменить условие if, чтобы избежать этой ошибки.
# Вы забыли поставить точку с запятой после переменных.
#
# Ваш код некорректно выполняет условия задания. Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. В данном случае, Ваш код сортирует цвета в алфавитном порядке, что не соответствует требованию выводить цвета, которые не разрешены для использования в проекте. Попробуйте изменить условия задания, чтобы учесть, что цвета должны быть отфильтрованы сначала по разрешенным, а затем по использованным и любимым цветам.
# Вы забыли поставить скобку после условия if.
# Ваш код некорректно выполняет условия задания. Вы используете sorted с аргументом reverse=False, что означает сортировку по возрастанию, но для вывода в алфавитном порядке нужно использовать sorted(..., reverse=True) для сортировки по убыванию. Попробуйте изменить условие сортировки.
# Ваш код некорректно выполняет условия задания. Вы вычитаете allowed_colors из пересечения used_colors и favorite_colors, что приведет к удалению всех разрешенных цветов из результата, а не наоборот. Попробуйте изменить порядок операций, чтобы сначала найти пересечение used_colors и favorite_colors, а затем вычесть allowed_colors.
# Ваш код некорректно выполняет условия задания. В данном коде не учитывается структура словаря studios, и он пытается работать напрямую с переменной studios, что приводит к ошибкам. Попробуйте изменить условие if, чтобы учесть структуру словаря studios.
# Ваш код некорректно выполняет условия задания. Внутренний цикл в вашем коде использует неправильную структуру итерации, так как значение value в вашем словаре студий — это словарь, а не список словарей. Попробуйте изменить условия итерации, чтобы правильно получить списки помещений для каждого поселка.
# Ваш код некорректно выполняет условия задания. Ваш код не учитывает, что ключи словаря `studios` — это названия студий, а значения — словари с названиями поселков и списками помещений. Попробуйте изменить условие if, чтобы правильно проверять наличие помещения в списках помещений для каждой студии.
# Ваш код некорректно выполняет условия задания. Например, условие if.
# Ваш код сортирует названия студий, а не поселков. Попробуйте изменить условие if, чтобы отсортировать поселки в обратном алфавитном порядке.
# Вы забыли поставить двоеточие после оператора "in".
#
# Попробуйте изменить условие if в цикле for, чтобы исправить синтаксическую ошибку.
# Ваш код добавляет все поселоки, где есть упоминание о помещении, а не только те, где оно действительно было спроектировано.
#
# Попробуйте изменить условие добавления в список residences или обратите внимание на то, чтобы правильно отфильтровать поселки, где помещение действительно было спроектировано.
# Ваш код некорректно выполняет условия задания. Например, условие if.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Например, он не выполняет условие "названия поселков должны идти в обратном алфавитном порядке". Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания, так как он сортирует названия поселков в прямом алфавитном порядке, а требуется сортировка в обратном алфавитном порядке.
#
# Попробуйте изменить условие if, чтобы исправить ошибку.
# Ваш код некорректно выполняет условие о сортировке поселков в обратном алфавитном порядке.
#
# Попробуйте изменить условие if в цикле for, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Программа не учитывает, что названия поселков должны идти в обратном алфавитном порядке, и может выводить дубликаты поселков, если помещение встречается в нескольких поселках.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условие о сортировке поселков в обратном алфавитном порядке.
#
# Попробуйте изменить условие if в цикле for, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Он добавляет в список residences все названия поселков, в которых не было указанного помещения, что приводит к неправильному определению поселков, где проводилась работа над этим помещением.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Вместо добавления названий поселков в множество (set), вы добавляете их в список (list), что приводит к дубликатам, если помещение встречается в нескольких поселках. Попробуйте изменить, чтобы использовать множество для уникальных поселков.
# Ваш код добавляет названия поселков в список `residences` в каждой итерации цикла, что приводит к дублированию поселков. После завершения цикла в `residences` будет список с названиями поселков, в которых студии занимались дизайном интерьера введенного помещения, включая дубликаты.
#
# Попробуйте изменить условие цикла, чтобы в список добавлялись только уникальные названия поселков.
# Ваш код некорректно выполняет условия задания. Вы добавляете названия поселков в список residences независимо от того, найдено ли в списке помещений указанное помещение. Это приведет к добавлению всех поселков, даже если помещение не найдено ни в одном из них.
#
# #### Попробуйте изменить:
#
# Условие if, чтобы добавить названия поселков в список residences только в случае, если указанное помещение найдено в списке.
# Ваш код некорректно выполняет условия задания. Программа не учитывает все возможные поселки, где могло быть выполнено интерьерное проектирование указанного помещения.
#
# Попробуйте изменить условие if, чтобы учесть все поселки и правильно отсортировать их в обратном алфавитном порядке.
# Ваш код некорректно выполняет условия задания.
#
# Ваш код некорректно выполняет условия задания. Например, если стоимость проекта будет больше 250 тыс. руб., то условие if не будет выполняться.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код вызывает SyntaxError: invalid syntax из-за неправильного использования скобок при вызове split() для последнего элемента строки.
#
# Вместо info[-1].split()[0] нужно использовать int(info[-1].split()[0].replace(' тыс. руб.', '')) для корректного извлечения числа из строки стоимости.
# Вы используете переменную file, которая не определена в Вашем коде. Вам нужно использовать my_file, который является итератором для чтения файла построчно. Попробуйте изменить file на my_file в цикле for.
# Вы забыли поставить двоеточие после цикла for.
#
# Попробуйте изменить строку for line in my file:
#
# for line in my_file:
#
# Добавьте двоеточие, чтобы завершить условие цикла.
# Ваш код некорректно выполняет условия задания.
#
# Ваш код не учитывает, что стоимость проекта указана в формате "<целое число> тыс. руб.", и для извлечения числа из строки необходимо удалить символы " тыс. руб.".
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Условие требует, чтобы стоимость проекта была указана в формате "<целое число> тыс. руб.", а Ваше решение пытается извлечь число из последнего элемента строки, который содержит "недель". Попробуйте изменить условие if, чтобы правильно получить стоимость проекта.
# Ваш код некорректно выполняет условия задания.
#
# Ваш код пытается преобразовать всю строку после запятой в число, что некорректно выполняет условия задания. Попробуйте изменить условие if для корректного извлечения числа из строки с стоимостью.
# Ваш код некорректно выполняет условия задания.
#
# Ваш код некорректно выполняет условия задания.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Например, код некорректно обрабатывает стоимость проекта. Попробуйте изменить условие проверки стоимости проекта следующим образом:
# ```python
# if info[-1].split()[0] <= week and int(info[-2].split()[0].replace(' тыс. руб.', '')) <= 250:
# ```
# Ваш код некорректно выполняет условия задания.
#
# Ваш код некорректно выполняет условия задания.
#
# Вы пытаетесь извлечь данные из строки, которая не соответствует формату.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Вы забыли поставить двоеточие после условия if.
#
# Ваш код некорректно выполняет условия задания. Вы сравниваете количество недель и стоимость проекта, что не соответствует условию задачи. Условие требует проверять количество недель для стоимости не более 250 тыс. руб., а не наоборот. Попробуйте изменить порядок проверки условий.
# Ваш код некорректно выполняет условия задания, так как не обрабатывает строку с стоимостью корректно.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
#
# Например, добавить условие, которое будет удалять " тыс. руб.".
# Ваш код некорректно выполняет условия задания, так как пытается извлекать информацию из строки, предполагая, что последние два элемента списка `info` содержат информацию о количестве недель и стоимости проекта. На самом деле, структура данных в файле может быть другой, и это предположение не всегда верно. Попробуйте изменить способ извлечения данных из строки, чтобы корректно обрабатывать данные в файле.
# Вы забыли поставить двоеточие после условия if.
#
# Ваш код некорректно выполняет условия задания. Вы сравниваете последний элемент списка (количество недель) с введенным значением, что верно, но не учитываете стоимость проекта. Попробуйте изменить условия сравнения, чтобы также учитывать стоимость проекта.
# Ваш код некорректно выполняет условия задания.
#
# Ваш код некорректно выполняет условия задания.
#
# Вы пытаетесь извлечь значение стоимости, используя `info[-2].split()[0]`, что неверно, так как `info[-2]` содержит строку "200 тыс. руб.", а не числовое значение.
#
# Вам нужно извлечь числовое значение стоимости, удалив при этом " тыс. руб.".
# Ваш код некорректно выполняет условия задания. Вы пытаетесь разделить строку по запятым, но не учитываете, что стоимость проекта записана в формате "<целое число> тыс. руб.", и Вам нужно извлечь именно это число для сравнения. Попробуйте изменить код для корректного извлечения числа из строки с стоимостью.
# Вы забыли поставить скобки после условия if.
#
# Ваш код некорректно выполняет условия задания.
#
# Попробуйте изменить условие if, чтобы исправить ошибку.
# Ваш код некорректно выполняет условия задания. Вы пытаетесь сравнить стоимость проекта (info[-2]) с 250, но это некорректно, так как стоимость проекта указана в формате "<целое число> тыс. руб.", и для сравнения нужно извлечь числовое значение из этой строки. Попробуйте изменить условия сравнения, чтобы правильно извлечь числовое значение стоимости и количество недель для сравнения.
# Ваш код некорректно выполняет условия задания. Так, он не учитывает стоимость проекта, которая также должна быть не более 250 тыс. руб. Скорректируйте ошибку, добавив условие if, проверяющее стоимость проекта.
# Ваш код некорректно выполняет условия задания.
#
# Ваш код пытается работать с данными, которые на самом деле находятся в info [-2], что не соответствует условию задания.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Например, он некорректно выполняет условие "вывести вещественное число — максимальная цена среди всех стоимостей предметов интерьера, которые были куплены студией дизайна". Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код не учитывает разделение между домами и не обрабатывает все предметы интерьера корректно.
#
# Попробуйте изменить условие if, чтобы учесть разделение между домами и правильно обработать все предметы интерьера.
# Ваш код некорректно выполняет условия задания. Программа не учитывает, что входные данные разделены точкой с запятой и пробелом, а не запятой и пробелом. Попробуйте изменить условие if.
# Вы забыли поставить двоеточие после условия цикла for.
#
# Попробуйте изменить условие цикла for, добавив двоеточие.
# Вы забыли поставить точку с запятой после условия if.
#
# Ваш код некорректно выполняет условия задания.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Вы забыли поставить двоеточие после условия if.
#
# Ваш код некорректно выполняет условия задания, потому что не учитывает цену, указанную после слова "руб." в строке. Попробуйте изменить условие if, чтобы включить правильное извлечение цены из строки.
# Ваш код некорректно выполняет условия задания. Программа не учитывает, что цена может быть дробной и что разделитель в строке может быть точкой с запятой и пробелом, а не просто точкой с запятой. Попробуйте изменить условие if, чтобы учитывать возможность дробных чисел и другие возможные разделители.
# Ваш код некорректно выполняет условия задания. Вместо того чтобы разбивать строки по разделителю ';' и ' ', вы используете '; ' для объединения строк, что приводит к неправильному разделению. Попробуйте изменить условие if.
# Ваш код некорректно выполняет условия задания. Ошибка в том, что Вы используете неверный разделитель.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Программа должна находить максимальную стоимость предметов интерьера среди трех домов, а ваш код не учитывает это требование. Попробуйте изменить условие if, чтобы учесть все три дома и найти максимальную стоимость трат.
# Ваш код некорректно выполняет условия задания. Ошибка заключается в том, что разделитель используется некорректно, что приводит к неправильному разделению строк. Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Вы пытаетесь найти минимальную цену вместо максимальной. Попробуйте изменить условие проверки в строке if k < max_pr: на if k > max_pr:, чтобы находить максимальную цену.
# Ваш код некорректно выполняет условия задания.
#
# Ваш код не выполняет условия задания, так как логика вычисления максимальной цены не учитывает все предметы интерьера для каждого дома, а сравнивает только последнюю найденную цену.
#
# Попробуйте изменить условие if, чтобы учесть все цены для каждого дома и найти максимальную из всех.
# Вы забыли поставить двоеточие после условия if.
#
# Ваш код некорректно выполняет условия задания.
#
# Попробуйте изменить условие if так, чтобы оно выглядело следующим образом:
#
# if k > max_pr: max_pr = k.
# Ошибка в логике: после разбиения строки на элементы и извлечения цены, переменная k используется для сравнения и обновления max_pr, но после цикла for переменная k уже не определена, и выводится не та переменная, которая нужна.
#
# Попробуйте изменить условие if, чтобы исправить ошибку.
# Ваш код некорректно выполняет условия задания. Переменная k не инициализирована до цикла for, что приведет к ошибке, когда k будет использоваться вне цикла. Попробуйте изменить условие if, чтобы переменная k была инициализирована до цикла.
# Вы забыли поставить двоеточие после определения функции.
#
# Попробуйте изменить условие if следующим образом:
#
# def work(slov):
#     counter = 0
#     money_done = 0
#     money_not_done = 0
#     for k, v in slov.items():
#         if v[1] == 'не реализован':
#             counter += 1
#             money_done += v[0]
#         if v[1] == 'реализован':
#             money_not_done += v[0]
#     if counter != 0:
#         return [money_done, False]
#     else:
#         return [money_not_done, True]
# Вы забыли поставить точку с запятой после условия if.
#
# Ваш код некорректно выполняет условия задания. Логика работы функции правильная, но она не учитывает, что функция work должна принимать на вход словарь, а в вашем решении нет аргумента для принимаемого словаря.
#
# Попробуйте изменить условие if, добавив точку с запятой.
# Вы забыли поставить скобку в конце конструкции if.
#
# Ваш код некорректно выполняет условия задания.
#
# Попробуйте изменить условие if, поставив скобку в конце конструкции.
# Ваш код некорректно выполняет условия задания. Вместо того, чтобы проходить по ключам и значениям словаря, Ваш код работает с ними некорректно, так как передает их в цикл в виде (k, v), что не соответствует условию задания.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Вы не обрабатываете корректно элементы кортежа, которые являются значениями словаря. Вам нужно проверять элементы кортежа, а не индексы.
#
# Попробуйте изменить условие if, чтобы правильно обрабатывать значения кортежей.
# Ваш код некорректно выполняет условия задания. Логика работы счетчика counter не учитывает, что если все проекты реализованы, counter останется равным 0, что приведет к возврату некорректного значения. Попробуйте изменить условие проверки на наличие нереализованных проектов.
# Вы забыли поставить две закрывающие скобки.
#
# Ваш код некорректно выполняет условия задания.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Вы забыли поставить двоеточие после условия.
#
# Попробуйте изменить условие if, добавив двоеточие.
# Вы забыли поставить двоеточие после оператора if и else.
#
# Попробуйте изменить условие if и условие else, добавив двоеточие.
# Ваш код некорректно выполняет условия задания. Логика проверки всех проектов на корректность реализации не учитывается. Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Вы неправильно применили условие if. Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Ваш код правильно считает сумму реализованных и нереализованных проектов, но некорректно определяет, был ли хотя бы один нереализованный проект. Попробуйте изменить условие проверки на наличие нереализованных проектов.
# Ваш код некорректно выполняет условия задания. Например, если все проекты реализованы, то функция должна возвращать список из двух значений: целое число — стоимость реализованных проектов, и логическую константу — True. Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания.
# Ваш код не выполняет условие задания, потому что функция не возвращает значения.
# Чтобы исправить ошибку, попробуйте изменить условие if на условие return.
# Ваш код некорректно выполняет условия задания.
#
# Ваш код не выполняет условие "если все проекты реализованы, то должна возвращаться сумма стоимостей всех реализованных проектов, а не сумма стоимостей нереализованных проектов".
#
# Попробуйте изменить условие if в теле функции.
# Ваш код некорректно выполняет условия задания.
#
# Ваш код должен возвращать список из двух значений: целое число — стоимость реализованных проектов, и логическую константу — True.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания.
#
# Ваш код не выполняет условие "Если были реализованы все проекты реализован, то функция возвращает список из двух значений: целое число — стоимость реализованных проектов, и логическую константу — True.".
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Например, функция возвращает результат после первого прохода по словарю, не проверяя все проекты. Попробуйте изменить условие if, чтобы проверка была полной.
# Вы забыли поставить кавычки вокруг переменной ton.
# Функция input() возвращает строку, которая должна быть заключена в кавычки в f-строке.
# Попробуйте изменить условие if.
# Вы забыли поставить закрывающую кавычку.
#
# Ваш код некорректно выполняет условия задания, потому что не выводит анализируемое средство выразительности.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Вы забыли закрыть кавычки в строке f-строки.
# Вы забыли поставить f-строку.
#
# Ваш код выполняет условия задания, но некорректно выполняет условия задания. Вместо того чтобы использовать значение переменной ton, выводится фиксированная строка "Сегодня мы будем анализировать метафоры в тексте!". Попробуйте изменить условие if, чтобы использовать значение переменной ton в выводе.
# Вы забыли поставить двоеточие после условия if.
# Ваш код некорректно выполняет условия задания.
# Попробуйте изменить условие if.
# Вы забыли поставить f-строку.
#
# Ваш код выполняет условия задания, но некорректно выполняет условия задания.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. В условии сказано, что в переменную ton считывается название средства выразительности, но в вашем решении ton считывается как целое число, а не как строка. Попробуйте изменить условие if.
# Вы забыли поставить кавычки при вызове функции print.
# Функция print() вызывается без кавычек, так как это встроенная функция Python.
# Попробуйте изменить условие if, чтобы исправить ошибку.
# Вы не указали, что именно выводить в переменную variant. Убедитесь, что переменная ton содержит правильное значение, прежде чем использовать ее в f-строке.
# Ваш код некорректно выполняет условия задания.
#
# *Ваш код должен выводить фразу вида 'Сегодня мы будем анализировать '<название средства выразительности>' в тексте!'.*
#
# *Попробуйте изменить* условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. В условии указано, что нужно проверять, что язык, на который нужно перевести текст, совпадает с введенным значением и что в тексте есть специальные термины. Ваш код проверяет только, что язык, на который нужно перевести текст, совпадает с введенным значением, но не учитывает наличие специальных терминов. Попробуйте изменить условия задания или скорректировать ошибку в коде.
# Вы не проверяете наличие специальных терминов в тексте.
#
# Попробуйте изменить условие if, чтобы учесть наличие специальных терминов.
# Вы забыли поставить скобку в условии if.
#
# Ваш код некорректно выполняет условия задания, потому что не проверяет наличие специальных терминов в тексте.
#
# Попробуйте изменить условие if так, чтобы проверять, что значение после последнего дефиса (специальные термины) равно 'есть', и только после этого проверять, что язык, на который нужно перевести текст, совпадает с введенным значением.
# Вы забыли поставить двоеточие после условия в операторе if.
#
# Ваш код некорректно выполняет условия задания.
# Вы забыли поставить двоеточие после условия if.
#
# Попробуйте изменить условие if, добавив двоеточие.
# Вы забыли поставить двоеточие после условия if.
#
# Попробуйте изменить условие if, чтобы исправить ошибку.
# Вы забыли закрыть скобку после вызова функции print().
#
# Попробуйте изменить код, добавив закрывающую скобку после функции print().
# Вы забыли поставить двоеточие после else.
#
# Попробуйте изменить условие if.
# Ваш код некорректно выполняет условия задания. В условии указано, что нужно проверять наличие специальных терминов в тексте, а Ваш код проверяет только наличие 'нет' в конце строки, что не соответствует условию. Попробуйте изменить условие if.
# Вы забыли поставить двоеточие после условия if.
#
# Ваш код некорректно выполняет условия задания, потому что Вы не проверили наличие специальных терминов в тексте.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Вы забыли поставить двоеточие после условия if.
#
# Ваш код некорректно выполняет условия задания, потому что Вы не проверяете, что в строке language содержится 'есть' в качестве части строки.
#
# Попробуйте изменить условие if.
# Ваш код некорректно выполняет условия задания, так как проверяет только наличие специальных терминов в тексте, а не проверяет соответствие языка, на который нужно перевести текст, введенному значению. Попробуйте изменить условие if, чтобы учесть оба условия.
# Ваш код некорректно выполняет условия задания.
# Ваш код проверяет только соответствие языков, но не учитывает наличие специальных терминов.
# Попробуйте изменить условие if, чтобы включить проверку наличия специальных терминов.
# Ваш код некорректно выполняет условия задания. Условие проверки наличия специальных терминов в тексте ("есть") не учитывается в вашем решении.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Вы забыли поставить == при сравнении строк. При сравнении двух строк следует использовать оператор ==.
# Вы забыли поставить кавычки при использовании функции print.
#
# Ваш код некорректно выполняет условия задания. Программа не учитывает, что количество слов в тексте указано в формате "<целое число> слов". Попробуйте изменить условие if, чтобы учесть этот формат.
# Вы забыли поставить & перед условием if.
#
# Ваш код некорректно выполняет условия задания.
#
# Попробуйте изменить условие if, чтобы исправить ошибку.
# Вы забыли поставить двоеточие после условия if.
#
# ...
# Попробуйте изменить код так, чтобы сохранить порядок без сортировки.
# Ваш код некорректно выполняет условия задания. Если шрифт не найден ни в одном из списков значений словаря design, то пустой список будет выведен как результат. Однако, если шрифт присутствует в одном или нескольких списках, но не во всех, то имена и фамилии этих дизайнеров будут выведены в правильном порядке, но без учета дубликатов, если шрифт присутствует в нескольких списках.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Например, условие if.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Вы забыли поставить двоеточие после определения функции.
#
# Попробуйте изменить Ваш код, чтобы исправить ошибку.
# Ваш код некорректно выполняет условия задания.
#
# Ваш код не возвращает результат функции, если нет агентств, удовлетворяющих условию. Попробуйте изменить условие if, чтобы учесть этот случай.
# Вы забыли поставить "s" после переменной names.
# Ваш код некорректно выполняет условия задания, потому что не все агентства добавляются в список agency.
# Ваш код некорректно выполняет условия задания. Например, код не выполняет условие "возвращать список с названиями таких агентств в алфавитном порядке". Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания.
#
# Ваш код возвращает список с названиями агентств, у которых не менее 500 положительных отзывов, но не учитывает, что названия агентств могут быть не в алфавитном порядке.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код выполняет условия задания, но некорректно выполняет условия задания. Ваш код разделяет строки на списки, но не преобразует строки в целые числа для сравнения с 500. Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Вы забыли поставить скобку в условном операторе if.
# Синтаксическая ошибка. Вы пытаетесь обратиться к переменной, которая не определена.
#
# Ваш код некорректно выполняет условия задания. Вы создаете пустой список agency внутри функции, который не будет виден за ее пределами, так как он локальный. Поэтому после завершения функции список agency будет пустым, и функция вернет его, даже если в нем нет элементов. Попробуйте изменить условие if, чтобы корректно собирать названия агентств с достаточным количеством положительных отзывов.
# Вы забыли поставить двоеточие после условия цикла for.
#
# Ваш код некорректно выполняет условия задания. Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Вы забыли поставить закрывающую скобку.
#
# Ваш код некорректно выполняет условия задания.
#
# Попробуйте изменить условие if.
# Ваш код некорректно выполняет условия задания.
#
# Ваш код не учитывает возможность несоответствия длины списков names и count. Это может привести к ошибкам при доступе к элементам списка count по индексу, если количество агентств в строках names и count не совпадает.
#
# Попробуйте изменить условие if так, чтобы оно учитывало возможность несоответствия длины списков names и count.
# Вы забыли поставить скобку после условия if.
# Ваш код некорректно выполняет условия задания.
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
#
# Код должен возвращать список с названиями агентств, у которых не менее 500 положительных отзывов, в алфавитном порядке.
# Вы забыли поставить скобку в условии if.
#
# Ваш код некорректно выполняет условия задания, так как Вы не соблюли все условия.
# Ваш код некорректно выполняет условия задания.
#
# Ваш код не выполняет условия задания, потому что Вы возвращаете только одно агентство, а не все.
#
# Попробуйте изменить условие if, чтобы исправить ошибку.
# Ваш код выполняет условия задания некорректно.
# Ваш код должен возвращать список с названиями агентств, а не выводить его.
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код не учитывает, что каждая строка может содержать информацию о нескольких выставках, разделенных запятой и пробелом.
#
# Попробуйте изменить условие if, чтобы учесть возможность нескольких выставок в одной строке.
# Вы забыли поставить закрывающую кавычку.
#
# Попробуйте изменить код, чтобы исправить синтаксическую ошибку.
# Вы забыли поставить кавычки при использовании f-строки.
# Ваш код некорректно выполняет условия задания, потому что Вы не учли, что данные разделяются запятой с пробелом.
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания, так как не учитывает переменную e3, которая не была определена в вашем решении. Условия задания требуют обработки данных для трех музеев, а ваше решение предполагает только два музея. Попробуйте изменить условия задания, чтобы включить все три музея.
# Ваш код не выполняет условия задания.
# Ваш код не учитывает названия выставок и сортирует только количество отзывов, что не соответствует требованию вывести названия двух самых популярных выставок.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код не выполняет условия задания.
# Ваш код не учитывает, что каждая строка содержит информацию о выставке и количество отзывов, а не просто числа. Попробуйте изменить условие if, чтобы правильно извлекать данные о выставках и количестве отзывов.
# Ваш код выполняет условия задания, но некорректно выполняет условия задания. Ваш код сохраняет количество отзывов в одном списке cnt, который перезаписывается на каждой итерации цикла. Попробуйте изменить условия задания, чтобы каждому музею соответствовал свой список отзывов.
# Вы забыли поставить двоеточие после условия if.
# Ваш код некорректно выполняет условия задания. Ошибка заключается в том, что вы не используете переменную i, которая содержит строку с информацией о выставке. Попробуйте изменить exh на i в строке review = int(exh.split(': ')[1]).
# Вы забыли поставить двоеточие после условия if.
# Ваш код некорректно выполняет условия задания. Вы не учитываете названия выставок, а только их количество отзывов. Попробуйте изменить условие if, чтобы учесть названия выставок и правильно отсортировать их по количеству отзывов.
# Ваш код некорректно выполняет условия задания. Обратите внимание, что данные о количестве отзывов не обрабатываются как числа, что приводит к ошибкам при сортировке и выводе результата. Попробуйте изменить условие if, чтобы исправить ошибку.
# Ваш код выполняет условия задания, но некорректно выполняет условие сортировки. Ваш код сохраняет количество отзывов для каждой выставки в список cnt, но этот список содержит количество отзывов, а не сами выставки. Попробуйте изменить логику сохранения и сортировки данных.
# Ваш код некорректно выполняет условия задания. Ошибка заключается в том, что в вашем решении не учитывается название выставки, а только количество отзывов. Попробуйте изменить условие if, чтобы учитывать и название, и количество отзывов, и отсортировать выставки по количеству отзывов.
# Ваш код некорректно выполняет условия задания. Например, Ваш код не учитывает, что каждая выставка может иметь несколько отзывов. Попробуйте изменить условие if, чтобы учесть возможность нескольких отзывов для каждой выставки.
# Ваш код выполняет условия задания, но некорректно выполняет условия задания. Ваш код не учитывает необходимость вывода двух самых популярных выставок, а просто выводит все отзывы, отсортированные по убыванию. Попробуйте изменить условия задания, чтобы выбрать только два самых популярных количества отзывов.
# Ваш код некорректно выполняет условия задания. Вы не учитываете названия выставок и сортируете только количества отзывов, что не соответствует требованию вывести топ-2 выставок по количеству отзывов.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код выполняет условия задания, но некорректно выполняет условия задания. Ваш код сохраняет количество отзывов для каждой выставки, но не сохраняет названия выставок. Попробуйте изменить условия задания, чтобы сохранять названия выставок и выводить их вместе с количеством отзывов.
# Ваш код предполагает, что data является списком, что не всегда верно, так как input() возвращает строку. Попробуйте изменить условия задания или код для корректного выполнения.
# Вы забыли поставить двоеточие после условия if.
# Ваш код некорректно выполняет условия задания.
# Попробуйте изменить условие if, чтобы исправить ошибку.
# Ваш код некорректно выполняет условия задания. Например, при вводе данных "Новая Третьяковка: август, октябрь, декабрь; Эрмитаж: январь, март, май; Пушкинский музей: февраль, апрель, июнь, август; Музей изобразительных искусств: январь, март, май, август" ожидается "Музей изобразительных искусств, Новая Третьяковка, Пушкинский музей", но выводится "Музей изобразительных искусств, Пушкинский музей, Новая Третьяковка".
#
# Ваш код некорректно выполняет условие if. Например, при вводе данных "Новая Третьяковка: август, октябрь, декабрь; Эрмитаж: январь, март, май; Пушкинский музей: февраль, апрель, июнь, август; Музей изобразительных искусств: январь, март, май, август" ожидается "Музей изобразительных искусств, Новая Третьяковка, Пушкинский музей", но выводится "Музей изобразительных искусств, Пушкинский музей, Новая Третьяковка".
#
# *Попробуйте изменить условие if, чтобы учитывать возможность нескольких месяцев.*
# Вы забыли поставить точку с запятой после условия if.
#
# Ваш код некорректно выполняет условия задания.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Вы неправильно разделили строку на название музея и доступные месяцы.
# Ваш код:
# museum, avail = info
#
# Вместо этого, попробуйте разделить строку на две части, используя пробел в качестве разделителя.
#
# *Обратите внимание, что это лишь один из возможных способов решения проблемы. Вы можете использовать его в качестве подсказки или решить задачу любым другим удобным для вас способом.*
# Вы забыли поставить двоеточие после условия if.
# Ваш код некорректно выполняет условия задания.
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Например, Вы добавляете в список result не названия музеев, а целые строки с названием музея и месяцами. Попробуйте изменить условие if, чтобы добавлять только названия музеев.
# Вы забыли поставить двоеточие после условия if.
# Ваш код некорректно выполняет условия задания.
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Вы добавляете в список названия музеев целиком, а не их названия. Попробуйте изменить условие if.
# Ваш код некорректно выполняет условия задания. Например, он не выполняет условие "названия должны выводиться через запятую и пробел в алфавитном порядке". Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания.
#
# Ваш код не выполняет условие "если месяц Алины (переменная из п.2) есть в месяцах музея, то добавьте название музея в список из п.3".
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания.
#
# Ваш код некорректно выполняет условие задания. Попробуйте изменить условие вывода результата.
# Ваш код некорректно выполняет условия задания.
#
# Ваш код не выполняет условие "если месяц Алины (переменная из п.2) есть в месяцах музея, то добавьте название музея в список из п.3".
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет сортировку в обратном алфавитном порядке. В условии указано, что названия музеев должны выводиться в алфавитном порядке, а ваше решение сортирует их в обратном порядке.
#
# Попробуйте изменить условие if.
# Ваш код некорректно выполняет условия задания.
#
# Ваш код не выполняет условие "выведите названия музеев, которые устраивают Алину (где она может провести выставку), через запятую и пробел в алфавитном порядке".
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Ошибка заключается в том, что условие проверки доступности музея для Алины не учитывает возможность нескольких месяцев. Если музей может провести выставку в нескольких месяцах, нужно проверять, что хотя бы один из этих месяцев совпадает с желаемым месяцем Алины.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Вы забыли поставить двоеточие после имени функции.
#
# Попробуйте изменить Ваш код, поставив двоеточие после имени функции.
# Ваш код некорректно выполняет условия задания.
#
# Ваш код не выполняет условие, что студия дизайна успешна, если она не выиграла премию ни в один из годов, но при этом есть годы с положительной чистой прибылью.
#
# Попробуйте изменить условие if, чтобы учесть все возможные случаи.
# Ваш код некорректно выполняет условия задания. Логика проверки успешности студии дизайна не учитывает возможность побед в разные годы.
#
# Попробуйте изменить условие if, чтобы учесть возможность побед в разные годы.
# Ошибка в вашем коде заключается в том, что вы обращаетесь к элементам словаря некорректно. Вы передаете словарь, где ключами являются отчетные годы, а значениями — кортежи с чистой прибылью и результатом выигрыша премии. Ваш цикл for должен проходить по парам ключ-значение, где k — это год, а v — это кортеж. Вам нужно извлекать элементы кортежа для проверки и обновления счетчиков.
# Ваш код некорректно выполняет условия задания. Если студия дизайна не выигрывала премию ни в один год, то функция должна возвращать сумму чистой прибыли за все отчетные годы. Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Синтаксическая ошибка.
# Ваш код пытается присвоить значение переменной, вместо того, чтобы сравнить ее с другим значением.
# Попробуйте изменить знак = на ==.
# Вы забыли поставить скобку после условия if.
#
# Ваш код некорректно выполняет условия задания.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Логика проверки количества побед не учитывает, что победы могут быть в разных годах, а не только в одном. Попробуйте изменить условие проверки побед так, чтобы оно учитывало возможность нескольких побед в разные годы.
# Ваш код некорректно выполняет условия задания. Если студия дизайна выигрывала премию хотя бы в один год, то функция должна возвращать логическую константу True. Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Логика проверки успешности студии дизайна не учитывает, что если студия выиграла премию хотя бы в один год, то она не может считаться успешной. Попробуйте изменить условие проверки на противоположное: если студия не выиграла премию ни в одном году, то вернуть True, иначе вернуть сумму чистой прибыли.
# Ваш код некорректно выполняет условия задания. Вы неправильно интерпретируете логику проверки побед. Если количество побед равно количеству отчетных лет, то функция должна возвращать True, а не сумму чистой прибыли.
# Ваш код некорректно выполняет условия задания. Вы не учитываете, что если студия ни разу не выигрывала премию, то функция должна возвращать True, а не сумму чистой прибыли. Попробуйте изменить условие if, чтобы исправить ошибку.
# Ваш код некорректно выполняет условия задания. Например, условие if.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Ваш код некорректно выполняет условия задания. Если студия ни разу не выигрывала премию, то должна возвращаться сумма чистой прибыли за все годы, а не список, где первый элемент всегда False. Попробуйте изменить условие возврата в зависимости от результатов проверки побед.
# Ваш код некорректно выполняет условия задания. Если студия выиграла премию хотя бы в один год, функция должна возвращать сумму чистой прибыли за все годы, а не количество побед. Попробуйте изменить условие if, чтобы учесть возможность побед в разные годы.
# Ваш код выполняет условия задания некорректно. Так, функция должна возвращать значение, а не выводить его.
#
# Попробуйте изменить условие if, чтобы скорректировать ошибку.
# Количество реально отправленных запросов: 316
# 0

# %%
if df_solutions_test['response'].isna().sum() == 0:
    df_solutions_test.to_csv('after_model.csv')
assert df_solutions_test['response'].isna().sum() == 0

# %%
df_solutions_test.head(10)
# Out:
#    id  task_id                                   student_solution  \
# 0   0        0  discount  = float(input())\nmoney = int(input(...
# 1   1        0  discount  = float(input())\nmoney = int(input(...
# 2   2        0  discount  = float(input())\nmoney = int(input(...
# 3   3        0  discount  = float(input())\nmoney = int(input(...
# 4   4        0  discount  = float(input())\nmoney = int(input(...
# 5   5        0  discount  = float(input())\nmoney = int(input(...
# 6   6        0  discount  = float(input())\nmoney = int(input(...
# 7   7        0  discount  = float(input())\nmoney = int(input(...
# 8   8        0  discount  = float(input())\nmoney = int(input(...
# 9   9        0  discount  = float(input())\nmoney = int(input(...
#
#                                       author_comment  \
# 0  Вы забыли поставить f перед кавычками.\n\nF-ст...
# 1  Вы забыли поставить знак нижнего подчеркивания...
# 2  Обратите внимание, что в условии if некорректн...
# 3  Обратите внимание, что в вашем коде ошибка в и...
# 4  Вы забыли поставить закрывающую скобку.\n\nВаш...
# 5  Вы задаете переменные внутри функции. Использу...
# 6  Обратите внимание, что в вашем коде отсутствуе...
# 7  Вы забыли поставить двоеточие после условия if...
# 8  Обратите внимание, что в условии if некорректн...
# 9  Обратите внимание, что в вашем коде использует...
#
#                             author_comment_embedding  \
# 0  -0.17573341727256775 -1.5086625814437866 -0.04...
# 1  0.011998751200735569 -1.380739688873291 -0.126...
# 2  -0.19097886979579926 -1.2001698017120361 0.292...
# 3  -0.15660114586353302 -1.6097294092178345 0.159...
# 4  -0.16214852035045624 -1.6376426219940186 -0.03...
# 5  -0.4415212571620941 -1.387903094291687 0.05415...
# 6  -0.18255430459976196 -1.794442057609558 0.1916...
# 7  -0.045173365622758865 -1.5382368564605713 -0.1...
# 8  -0.03325178846716881 -1.628157377243042 -0.130...
# 9  -0.5637627243995667 -1.7270963191986084 0.4514...
#
#                                      problem_message  \
# 0
# 1  unterminated string literal (detected at line ...
# 2  unterminated string literal (detected at line ...
# 3
# 4
# 5  unterminated string literal (detected at line ...
# 6
# 7              unexpected indent (<unknown>, line 6)
# 8           '(' was never closed (<unknown>, line 6)
# 9
#
#                                       line_with_code        error_type  \
# 0
# 1  print(f'Реализация проекта будет стоить {money...       SyntaxError
# 2  print(fРеализация проекта будет стоить {money}...       SyntaxError
# 3
# 4
# 5  print(f"Реализация проекта будет стоить {money...       SyntaxError
# 6
# 7      print(f'Реализация проекта будет стоить {m...  IndentationError
# 8  print(f'Реализация проекта будет стоить {money...       SyntaxError
# 9
#
#    code_problem                                        description  \
# 0         False  Реализуйте программу, которая напечатает стоим...
# 1          True  Реализуйте программу, которая напечатает стоим...
# 2          True  Реализуйте программу, которая напечатает стоим...
# 3         False  Реализуйте программу, которая напечатает стоим...
# 4         False  Реализуйте программу, которая напечатает стоим...
# 5          True  Реализуйте программу, которая напечатает стоим...
# 6         False  Реализуйте программу, которая напечатает стоим...
# 7          True  Реализуйте программу, которая напечатает стоим...
# 8          True  Реализуйте программу, которая напечатает стоим...
# 9         False  Реализуйте программу, которая напечатает стоим...
#
#                                      author_solution  error_open_tests  \
# 0  discount  = float(input())\nmoney = int(input(...             False
# 1  discount  = float(input())\nmoney = int(input(...             False
# 2  discount  = float(input())\nmoney = int(input(...             False
# 3  discount  = float(input())\nmoney = int(input(...             False
# 4  discount  = float(input())\nmoney = int(input(...             False
# 5  discount  = float(input())\nmoney = int(input(...             False
# 6  discount  = float(input())\nmoney = int(input(...             False
# 7  discount  = float(input())\nmoney = int(input(...             False
# 8  discount  = float(input())\nmoney = int(input(...             False
# 9  discount  = float(input())\nmoney = int(input(...             False
#
#    error_closed_tests test_info  \
# 0               False        []
# 1               False        []
# 2               False        []
# 3               False        []
# 4               False        []
# 5               False        []
# 6               False        []
# 7               False        []
# 8               False        []
# 9               False        []
#
#                                       system_message  \
# 0  Вы — профессиональный программист и наставник,...
# 1  Вы — профессиональный программист и наставник,...
# 2  Вы — профессиональный программист и наставник,...
# 3  Вы — профессиональный программист и наставник,...
# 4  Вы — профессиональный программист и наставник,...
# 5  Вы — профессиональный программист и наставник,...
# 6  Вы — профессиональный программист и наставник,...
# 7  Вы — профессиональный программист и наставник,...
# 8  Вы — профессиональный программист и наставник,...
# 9  Вы — профессиональный программист и наставник,...
#
#                                         request_text  \
# 0  Есть задача, описанная так: $Реализуйте програ...
# 1  Есть задача, описанная так: $Реализуйте програ...
# 2  Есть задача, описанная так: $Реализуйте програ...
# 3  Есть задача, описанная так: $Реализуйте програ...
# 4  Есть задача, описанная так: $Реализуйте програ...
# 5  Есть задача, описанная так: $Реализуйте програ...
# 6  Есть задача, описанная так: $Реализуйте програ...
# 7  Есть задача, описанная так: $Реализуйте програ...
# 8  Есть задача, описанная так: $Реализуйте програ...
# 9  Есть задача, описанная так: $Реализуйте програ...
#
#                                             response resp_lenght sentence_cnt
# 0  Вы забыли поставить f перед кавычками.\n\nF-ст...         177            4
# 1  Вы забыли поставить знак нижнего подчеркивания...         114            3
# 2  Обратите внимание, что в условии if некорректн...         184            3
# 3  Обратите внимание, что в вашем коде ошибка в и...         195            3
# 4  Вы забыли поставить закрывающую скобку.\n\nВаш...         150            4
# 5  Вы задаете переменные внутри функции. Использу...          91            3
# 6  Обратите внимание, что в вашем коде отсутствуе...         224            4
# 7  Вы забыли поставить двоеточие после условия if...         105            3
# 8  Обратите внимание, что в условии if некорректн...         180            4
# 9  Обратите внимание, что в вашем коде использует...         251            3

# %%
# Функция для логирования
def log_action(message):
    print(f"LOG: {message}")

# Проходим по строкам обоих датафреймов
for i in range(len(df_solutions_test)):
    error_open_tests = df_solutions_test.loc[i, 'error_open_tests']
    error_closed_tests = df_solutions_test.loc[i, 'error_closed_tests']
    
    if error_open_tests and error_closed_tests:
        df_solutions_test.at[i, 'author_comment'] = "Ошибка в скрытых и открытых тестах.\n\n " + df_solutions_test.at[i, 'response']
        log_action(f"Row {i}: Added 'Ошибка в скрытых и открытых тестах.' to response")
    elif error_open_tests:
        df_solutions_test.at[i, 'author_comment'] = "Ошибка в открытых тестах.\n\n " + df_solutions_test.at[i, 'response']
        log_action(f"Row {i}: Added 'Ошибка в открытых тестах.' to response")
    elif error_closed_tests:
        df_solutions_test.at[i, 'author_comment'] = "Ошибка в скрытых тестах.\n\n " + df_solutions_test.at[i, 'response']
        log_action(f"Row {i}: Added 'Ошибка в скрытых тестах.' to response")
# Out:
# LOG: Row 14: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 16: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 17: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 18: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 19: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 20: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 24: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 43: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 46: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 48: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 51: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 55: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 56: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 57: Added 'Ошибка в открытых тестах.' to response
# LOG: Row 58: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 66: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 67: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 69: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 70: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 72: Added 'Ошибка в скрытых тестах.' to response
# LOG: Row 73: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 74: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 75: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 76: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 77: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 78: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 79: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 80: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 82: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 83: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 84: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 85: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 86: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 87: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 88: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 89: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 92: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 93: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 94: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 134: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 139: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 142: Added 'Ошибка в скрытых тестах.' to response
# LOG: Row 143: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 144: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 145: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 146: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 147: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 149: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 150: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 151: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 152: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 153: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 157: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 158: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 159: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 160: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 161: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 162: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 163: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 164: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 165: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 166: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 169: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 171: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 175: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 176: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 178: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 184: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 186: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 187: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 188: Added 'Ошибка в скрытых тестах.' to response
# LOG: Row 189: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 210: Added 'Ошибка в открытых тестах.' to response
# LOG: Row 214: Added 'Ошибка в открытых тестах.' to response
# LOG: Row 216: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 217: Added 'Ошибка в открытых тестах.' to response
# LOG: Row 218: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 219: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 220: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 222: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 223: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 225: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 226: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 227: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 230: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 232: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 236: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 237: Added 'Ошибка в открытых тестах.' to response
# LOG: Row 239: Added 'Ошибка в открытых тестах.' to response
# LOG: Row 240: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 241: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 242: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 244: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 245: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 246: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 250: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 262: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 263: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 264: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 265: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 266: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 267: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 268: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 269: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 270: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 271: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 272: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 273: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 274: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 275: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 276: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 286: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 289: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 290: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 291: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 292: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 295: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 298: Added 'Ошибка в скрытых тестах.' to response
# LOG: Row 299: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 301: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 302: Added 'Ошибка в скрытых тестах.' to response
# LOG: Row 303: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 304: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 305: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 306: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 307: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 308: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 310: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 311: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 312: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 313: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 315: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 316: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 317: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 319: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 320: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 321: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 322: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 323: Added 'Ошибка в скрытых и открытых тестах.' to response
# LOG: Row 324: Added 'Ошибка в скрытых и открытых тестах.' to response

# %%
df_solutions_test = pd.read_csv('after_model.csv')

# %%
for index, row in tqdm(df_solutions_test.iterrows(), total=df_solutions_test.shape[0]):
    author_comment = row['author_comment'] 
    author_comment_embedding = embedding2string(get_sentence_embedding(author_comment)) 
    df_solutions_test.at[index, 'author_comment_embedding'] = author_comment_embedding
# Out:
# 100%|██████████| 325/325 [00:44<00:00,  7.24it/s]

# %%
# Выбираем нужные колонки
selected_df = df_solutions_test[['id', 'author_comment', 'author_comment_embedding']]

# Переименовываем колонку 'id' в 'solution_id'
selected_df.rename(columns={'id': 'solution_id'}, inplace=True)

# Сохраняем результат в CSV файл
selected_df.to_csv('submit_finetunedYA-m0.3-DEEP-v3-2.csv', index=False)
# Out:
# /tmp/ipykernel_6854/3218049726.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df.rename(columns={'id': 'solution_id'}, inplace=True)

# %%
TEST_SIZE = 325
EMBEDDING_SIZE = 768


def _check_ids_correctness(submit_df: pd.DataFrame, submit_example_df: pd.DataFrame) -> bool:
    not_presented = set(submit_example_df["solution_id"]) - set(submit_df["solution_id"])
    not_needed = set(submit_df["solution_id"]) - set(submit_example_df["solution_id"])

    not_presented = list(not_presented)
    not_presented.sort()
    not_needed = list(not_needed)
    not_needed.sort()

    error_message = "Submit is incorrect."
    if len(not_presented) + len(not_needed) > 0:
        if len(not_presented) > 0:
            error_message += f" Not presented solution_id: {not_presented}."
        if len(not_needed) > 0:
            error_message += f" Not needed solution_id: {not_needed}."
        raise ValueError(error_message)
    return True


def _check_rows_size_correctness(submit_df: pd.DataFrame) -> bool:
    incorrect_rows = []
    for idx in range(TEST_SIZE):
        if len(string2embedding(submit_df["author_comment_embedding"].iloc[idx])) != EMBEDDING_SIZE:
            incorrect_rows.append(idx)
    if len(incorrect_rows) > 0:
        raise ValueError(f"Submit has incorrect rows: {incorrect_rows}. (incorrect size of embedding)")
    return True


def check_submit_correctness(submit_path: str, submit_example_path: str) -> bool:
    if not submit_path.endswith(".csv"):
        raise ValueError(f"{submit_path} is not a .csv file.")

    submit_df = pd.read_csv(submit_path)
    submit_example_df = pd.read_csv(submit_example_path)

    _check_ids_correctness(submit_df, submit_example_df)
    _check_rows_size_correctness(submit_df)

    return True

check_submit_correctness(submit_path="submit_finetunedYA-m0.3-DEEP-v3.csv", submit_example_path="submit_example.csv")
# Out:
# True

# %%
import torch
from transformers import BertModel, BertTokenizer
import pandas as pd

model_name = "DeepPavlov/rubert-base-cased-sentence"
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)

#information that we have parsed form linter info
yulya_df = pd.read_excel('../data/new-data/data_with_tests_info_test18_10.xlsx')
roma_df = pd.read_csv('submit_finetunedYA-m0.3-DEEP-v3.csv')
roma_df['result_linter_ru'] = yulya_df['result_linter_ru']
roma_df['author_comment'] = roma_df.apply(lambda x: x['result_linter_ru'] if not pd.isna(x['result_linter_ru']) else x['author_comment'], axis = 1)

def get_sentence_embedding(sentence: str) -> torch.Tensor:
    inputs = tokenizer(sentence, return_tensors="pt", truncation=True, padding=True, max_length=128)
    with torch.no_grad():
        outputs = model(**inputs)
        embedding = outputs.last_hidden_state[:, 0, :].squeeze()
    return embedding

def embedding2string(embedding: torch.Tensor) -> str:
    return " ".join([str(i) for i in embedding.tolist()])

roma_df['author_comment_embedding'] = roma_df['author_comment'].apply(lambda x: embedding2string(get_sentence_embedding(x)))

roma_df[["solution_id", "author_comment", "author_comment_embedding"]].to_excel('submit_finetunedYA-m0.3-DEEP-v3.xlsx')
roma_df[["solution_id", "author_comment", "author_comment_embedding"]].to_csv('submit_finetunedYA-m0.3-DEEP-v3.csv', index=False)
# Out:
# /home/choosen-one/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
